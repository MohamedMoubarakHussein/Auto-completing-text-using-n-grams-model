# %%
import json
import os
import nltk
import random
import math
import re
from collections import OrderedDict

# %%
base = "C:\\Users\\RE-PC\\Desktop\\selected\\\Dataset\\"

'''
    dict_1 = {"Name of file" : dictonary}
    dictonary = {'data' : data_2 }
    dic_2 = {text : "string"}
    

'''
full_q = []
for x in os.listdir(base):
    with open(base+x ,'r') as f:
        d = json.load(f)
        x= x.replace(".json" , "")
        d=d[x]

        for i in d:
            each_list = i['data']
            q =""
            for i in each_list:
                q = q + i['text']
            full_q.append(q)

print(len(full_q))
print(full_q[0])
# Out:
# 13784
# Add another song to the Cita Romantica playlist.

# %%
def process(full_q):
    ls = []
    for i in full_q:
        i = re.sub(r'\d' , '' , i)
        i = i.lower()
        i = nltk.word_tokenize(i)
        ls.append(i)
    full_q = ls
    return full_q

full_q =process(full_q)
print(full_q[0])
# Out:
# ['add', 'another', 'song', 'to', 'the', 'cita', 'romantica', 'playlist', '.']

# %%
test_full_q = []
for i in range(2000):
    x = random.choice(full_q)
    test_full_q.append(x);
    full_q.remove(x)
print(len(test_full_q))
print(len(full_q))
print(test_full_q[144])
print(full_q[144])
# Out:
# 2000
# 11784
# ['show', 'the', 'whispering', 'willows', 'novel']
# ['please', 'add', 'liberty', 'forever', 'to', 'the', 'road', 'trip', 'playlist', '.']

# %%
def get_vocab(full_q):
    vocab = {}
    for i in full_q:
        for j in i:
            if(j not in vocab):
                vocab[j] = 1
            else:
                vocab[j] += 1
    return vocab
vocab = get_vocab(full_q)
print(vocab)
# Out:
# {'add': 1372, 'another': 49, 'song': 374, 'to': 2939, 'the': 6366, 'cita': 1, 'romantica': 4, 'playlist': 1151, '.': 2021, 'clem': 2, 'burke': 5, 'in': 2964, 'my': 1206, 'pre-party': 8, 'r': 26, '&': 118, 'b': 49, 'jams': 13, 'live': 57, 'from': 907, 'aragon': 2, 'ballroom': 1, 'trapeo': 4, 'unite': 2, 'and': 807, 'win': 2, 'night': 61, 'out': 631, 'piano': 20, 'bar': 99, 'cindy': 1, 'wilson': 6, 'spanish': 11, 'harlem': 3, 'incident': 2, 'cleaning': 7, 'house': 249, 'greyest': 1, 'of': 2204, 'blue': 15, 'skies': 4, 'indie': 52, 'espanol': 12, 'name': 33, 'kids': 15, 'street': 19, 'plylist': 1, 'new': 159, 'mix': 7, 'album': 404, 'radar': 3, 'latino': 11, 'tranquility': 1, 'latin': 37, 'pop': 49, 'rising': 12, 'd': 4, 'flame': 5, 'dcode': 2, 'fairy': 8, 'tales': 11, 'i': 1900, 'love': 109, 'neo': 5, 'soul': 43, 'national': 101, 'treasure': 2, 'book': 1375, 'secrets': 9, 'fire': 29, 'wind': 22, 'digster': 9, 'future': 12, 'hits': 53, 'caleigh': 2, 'peters': 4, 'women': 52, 'country': 49, 'list': 150, 'children': 9, 'telepathic': 1, 'experiences': 1, 'named': 31, 'baladas': 1, 'romanticas': 1, 'th': 89, 'inning': 1, 'bossa': 3, 'nova': 4, 'dinner': 32, 'need': 328, 'tune': 206, 'legendary': 3, 'guitar': 10, 'solos': 3, 'slimm': 2, 'cutta': 2, 'calhoun': 2, 'this': 1008, 'is': 1420, 'prince': 12, 'always': 8, 'dena': 2, "'s": 504, 'baroque': 2, 'spotify': 75, 'picks': 9, 'sleepytime': 1, 'an': 125, 'la': 41, 'mejor': 18, 'musica': 13, 'dance': 39, 'hey': 1, ',': 682, 'johnnie': 2, 'cope': 2, 'are': 288, 'ye': 2, 'waking': 1, 'yet': 3, 'year': 45, 'metal': 70, 'psychedelic': 6, 'rock': 84, 'can': 509, 'you': 319, 'esquivando': 1, 'charcos': 1, 'entitled': 12, 'wiktor': 1, 'coj': 1, 'sleep': 8, 'incorporate': 6, 'time': 245, 'warp': 2, 'into': 42, 'maksim': 1, 'trad': 2, 'folk': 29, 'eletro': 2, 'br': 2, 'dinnertime': 3, 'acoustics': 3, 'monsters': 2, 'a': 3757, 'chill': 33, 'vibes': 15, 'track': 257, 'spain': 7, 'top': 98, 'put': 208, 'by': 720, 'mike': 15, 'tramp': 2, 'on': 1018, 'deathcore': 5, 'ross': 5, 'boss': 4, 'laurie': 2, 'listas': 4, 'de': 74, 'exitos': 8, 'some': 274, 'beatmaster': 1, 'v': 2, 'nicky': 5, 'jam': 7, 'paulinho': 5, 'da': 11, 'viola': 5, 'radio': 13, 'artist': 158, 'queen': 17, 'olga': 3, 'souza': 3, 'virginia': 10, 'femme': 2, 'fatale': 2, 'm': 2, 'g': 6, 'sreekumar': 1, 'laidback': 1, 'acoustic': 25, 'orchestra': 4, 'cello': 4, 'want': 550, 'goldy': 1, 'mcjohn': 1, 'party': 170, 'noreen': 2, 'fresh': 23, 'finds': 10, 'six': 76, 'strings': 2, 'shawnna': 1, 'warm': 49, 'hearts': 7, 'feel': 21, 'good': 51, 'save': 5, 'firehouse': 2, 'david': 17, 'cole': 4, 'totally': 5, 'stress': 6, 'free': 12, 'progress': 3, 'clasica': 2, 'para': 12, 'todos': 1, 'tony': 7, 'thompson': 4, 'canta': 2, 'en': 8, 'ducha': 2, 'mozart': 4, 'downtempo': 2, 'beats': 5, 'passion': 6, 'kudai': 2, 'us': 17, 'vl': 1, 'how': 101, 'week': 49, 'end': 12, 'kirk': 3, 'hammett': 2, 'calm': 8, 'down': 18, 'with': 283, 'show': 706, 'beast': 5, 'mode': 2, 'kjetil': 2, 'vidar': 2, 'haraldstad': 2, 'krystal': 1, 'onto': 79, 'selektor': 5, '?': 1008, 'jazz': 35, 'for': 2608, 'loving': 8, 'couples': 4, 'needs': 16, 'more': 16, 'push': 3, 'button': 3, 'gina': 1, 'schock': 1, 'workout': 30, 'twerkout': 3, 'cristina': 1, 'endorphin': 5, 'rush': 9, 'it': 602, 'southern': 24, 'thing': 8, 'runaljod': 1, 'gap': 1, 'var': 1, 'ginnunga': 1, 'ashlee': 1, 'titled': 48, 'forever': 17, 'orange': 2, 'green': 18, 'los': 15, 'liza': 1, 'oumarova': 1, 'steampunk': 3, 'please': 291, 'ines': 2, 'called': 301, 'todo': 10, 'absolutely': 2, 'sweet': 11, 'marie': 1, 'gn': 1, 'blood': 19, 'face': 4, 'heartland': 2, 'spring': 25, 'classical': 30, 'partners': 3, 'crime': 4, 'added': 24, 'tomohisa': 1, 'yamashita': 1, 'conexiones': 6, 'written': 2, 'red': 25, 'feeling': 3, 'open': 41, 'concentration': 5, 'play': 1642, 'entire': 2, 'sonntag': 1, 'assassin': 2, 'creed': 1, 'francis': 2, 'healy': 2, 'rockin': 2, "'": 22, 'gareth': 2, 'gates': 5, 'autumn': 18, 'sxsw': 6, 'verano' ...

# %%
closed_vocab = []
for i in vocab:
    if(vocab[i] > 1):
        closed_vocab.append(i)

# %%
new_full_q = []
for i in full_q:
    new = []
    for j in i:
        if(j in closed_vocab):
            new.append(j)
        else:
            new.append("<unk>")
    new_full_q.append(new)
full_q = new_full_q
full_q
# Out:
# [['add',
#   'another',
#   'song',
#   'to',
#   'the',
#   '<unk>',
#   'romantica',
#   'playlist',
#   '.'],
#  ['add',
#   'clem',
#   'burke',
#   'in',
#   'my',
#   'playlist',
#   'pre-party',
#   'r',
#   '&',
#   'b',
#   'jams'],
#  ['add', 'live', 'from', 'aragon', '<unk>', 'to', 'trapeo'],
#  ['add', 'unite', 'and', 'win', 'to', 'my', 'night', 'out'],
#  ['add', 'the', 'piano', 'bar', 'to', 'my', '<unk>', 'wilson'],
#  ['add', 'spanish', 'harlem', 'incident', 'to', 'cleaning', 'the', 'house'],
#  ['add',
#   'the',
#   '<unk>',
#   'of',
#   'blue',
#   'skies',
#   'in',
#   'indie',
#   'espanol',
#   'my',
#   'playlist'],
#  ['add',
#   'the',
#   'name',
#   'kids',
#   'in',
#   'the',
#   'street',
#   'to',
#   'the',
#   '<unk>',
#   'new',
#   'indie',
#   'mix'],
#  ['add', 'album', 'radar', 'latino'],
#  ['add', '<unk>', 'to', 'the', 'latin', 'pop', 'rising', 'playlist', '.'],
#  ['add', 'd', 'flame', 'to', 'the', 'dcode', 'playlist', '.'],
#  ['add', 'album', 'to', 'my', 'fairy', 'tales'],
#  ['add',
#   'to',
#   'playlist',
#   'i',
#   'love',
#   'my',
#   'neo',
#   'soul',
#   'the',
#   'name',
#   'national',
#   'treasure',
#   'book',
#   'of',
#   'secrets'],
#  ['add',
#   'the',
#   'fire',
#   'and',
#   'the',
#   'wind',
#   'to',
#   'my',
#   'digster',
#   'future',
#   'hits',
#   'playlist',
#   '.'],
#  ['add', 'caleigh', 'peters', 'to', 'my', 'women', 'of', 'country', 'list'],
#  ['add',
#   'children',
#   'of',
#   '<unk>',
#   '<unk>',
#   'to',
#   'the',
#   'playlist',
#   'named',
#   '<unk>',
#   '<unk>'],
#  ['add', 'th', '<unk>', 'to', 'my', 'bossa', 'nova', 'dinner', 'playlist'],
#  ['i',
#   'need',
#   'another',
#   'tune',
#   'in',
#   'my',
#   'legendary',
#   'guitar',
#   'solos',
#   'playlist',
#   '.'],
#  ['add',
#   'slimm',
#   'cutta',
#   'calhoun',
#   'to',
#   'my',
#   'this',
#   'is',
#   'prince',
#   'playlist',
#   '.'],
#  ['add',
#   'always',
#   'to',
#   'dena',
#   "'s",
#   'baroque',
#   'spotify',
#   'picks',
#   'playlist',
#   '.'],
#  ['add', 'song', 'to', '<unk>'],
#  ['add', 'an', 'album', 'to', 'my', 'list', 'la', 'mejor', 'musica', 'dance'],
#  ['add',
#   '<unk>',
#   ',',
#   'johnnie',
#   'cope',
#   ',',
#   'are',
#   'ye',
#   '<unk>',
#   'yet',
#   'to',
#   'year',
#   'in',
#   'metal',
#   'playlist'],
#  ['add', 'the', 'album', 'to', 'the', 'psychedelic', 'rock', 'playlist'],
#  ['can',
#   'you',
#   'add',
#   '<unk>',
#   '<unk>',
#   'to',
#   'my',
#   'playlist',
#   'entitled',
#   'the',
#   'piano',
#   'bar'],
#  ['add', '<unk>', '<unk>', 'to', 'the', 'sleep', 'playlist', '.'],
#  ['incorporate',
#   'time',
#   'warp',
#   'into',
#   'my',
#   'fairy',
#   'tales',
#   'playlist',
#   '.'],
#  ['add', 'this', '<unk>', 'tune', 'to', 'trad', 'folk'],
#  ['add', 'tune', 'to', 'my', 'playlist', 'eletro', 'br'],
#  ['add', 'this', 'tune', 'to', 'my', 'dinnertime', 'acoustics', 'list'],
#  ['add', 'monsters', 'this', 'is', 'prince', 'playlist'],
#  ['add', 'a', 'tune', 'in', 'chill', 'vibes'],
#  ['can', 'you', 'add', 'a', 'track', 'to', 'my', 'spain', 'top', 'playlist'],
#  ['put', 'this', 'album', 'by', 'mike', 'tramp', 'on', 'deathcore'],
#  ['add',
#   'ross',
#   'the',
#   'boss',
#   'to',
#   'laurie',
#   "'s",
#   'listas',
#   'de',
#   'exitos',
#   'list'],
#  ['add',
#   'some',
#   '<unk>',
#   'v',
#   'to',
#   'the',
#   'this',
#   'is',
#   'nicky',
#   'jam',
#   'playlist',
#   '.'],
#  ['add',
#   'paulinho',
#   'da',
#   'viola',
#   'to',
#   'my',
#   'radio',
#   'rock',
#   'song',
#   'list'],
#  ['add', 'this', 'artist', 'to', 'queen', 'playlist'],
#  ['add',
#   'olga',
#   'souza',
#   'to',
#   'virginia',
#   "'s",
#   'femme',
#   'fatale',
#   'playlist'],
#  ['add',
#   'an',
#   'album',
#   'by',
#   'm',
#   'g',
#   '<unk>',
#   'to',
#   'my',
#   '<unk>',
#   'acoustic',
#   'playlist',
#   '.'],
#  ['add',
#   'this',
#   'album',
#   'to',
#   'my',
#   'spotify',
#   'orchestra',
#   'cello',
#   'playlist'],
#  ['i',
#   'want',
#   'to',
#   'put',
#   '<unk>',
#   '<unk>',
#   'on',
#   'my',
#   'rock',
#   'party',
#   'playlist'],
#  ['add',
#   'this',
#   'song',
#   'to',
#   'noreen',
#   "'s",
#   'fresh',
#   'finds',
#   'six',
#   'strings'],
#  ['a',
#   '<unk>',
#   'to',
#   'the',
#   'warm',
#   'hearts',
#   'feel',
#   'good',
#   'playlist',
#   '.'],
#  ['add', 'this', 'tune', 'to', 'rock', 'save', 'the', 'queen'],
#  ['add', 'firehouse', 'to', 'my', 'acoustic', 'soul', 'list', '.'],
#  ['add',
#   'this',
#   'david',
#   'cole',
#   'track',
#   'to',
#   'my',
#   'totally',
#   'stress',
#   'free'],
#  ['add', 'progress', 'to', 'my', 'clasica', 'para', '<unk>', 'playlist', '.'],
#  ['add',
#   'the',
#   'artist',
#   'tony',
#   'thompson',
#   'to',
#   'my',
#   'canta',
#   'en',
#   'la',
#   'ducha',
#   'playlist'],
#  ['add', 'the', 'artist', 'to', 'my', 'this', 'is', 'mozart', 'playlist', '.'],
#  ['add', 'this', 'track', 'to', 'downtempo', 'beats'],
#  ['add',
#   'feel',
#   'the',
#   'passion',
#   'to',
#   'my',
#   'this',
#   'is',
#   'kudai',
#   'playlist',
#   '.'],
#  ['add', 'this', 'song', 'to', 'my', 'us', 'latin', 'top', 'playlist'],
#  ['add', '<unk>', 'mike', 'to', 'my', 'dcode', 'playlist'],
#  ['add', 'how', 'to', 'my', 'week', 'end', 'playlist'],
#  ['add', 'kirk', 'hammett', 'to', 'calm', 'down'],
#  ['add', 'on', 'with', 'the', 'show', 'to', 'my', 'beast', 'mode', 'playlist'],
#  ['add', 'kjetil', 'vidar', 'haraldstad', 'to', 'listas', 'de', 'exitos'],
#  ['add', 'this', 'track', 'to', '<unk>', "'s", 'piano'],
#  ['can',
#   'you',
#   'put',
#   'this',
#   'track',
#   'onto',
#   'the',
#   'playlist',
#   'the',
#   'selektor',
#   '?'],
#  ['my',
#   'jazz',
#   'for',
#   'loving',
#   'couples',
#   'needs',
#   'more',
#   'push',
#   'the',
#   'button'],
#  ['add', '<unk>', '<unk>', 'to', 'workout', 'twerkout'],
#  ['add', 'this', 'tune', 'to', '<unk>', "'s", 'endorphin', 'rush', 'playlist'],
#  ['add',
#   'this',
#   'tune',
#   'to',
#   'my',
#   'it',
#   "'s",
#   'a',
#   'southern',
#   'thing',
#   'playlist'],
#  ['add', 'this', 'tune', 'to', 'this', 'is', 'nicky', 'jam'],
#  ['add',
#   '<unk>',
#   '<unk>',
#   '<unk>',
#   '<unk>',
#   'to',
#   '<unk>',
#   "'s",
#   'playlist',
#   'titled',
#   'forever',
#   'country'],
#  ['put',
#   'the',
#   'orange',
#   'and',
#   'the',
#   'green',
#   'on',
#   'los',
#   'radio',
#   'exitos'],
#  ['add',
#   'an',
#   'album',
#   'by',
#   '<unk>',
#   '<unk>',
#   'to',
#   'the',
#   'steampunk',
#   'playlist',
#   '.'],
#  ['please',
#   'add',
#   'a',
#   'song',
#   'to',
#   'ines',
#   "'s",
#   'playlist',
#   'called',
#   'metal',
#   'party'],
#  ['for', 'playlist', 'todo', 'latino', 'add', 'absolutely', 'sweet', '<unk>'],
#  ['add', '<unk>', 'to', 'night', 'vibes'],
#  ['can',
#   'you',
#   'add',
#   'blood',
#   'on',
#   'the',
#   'face',
#   'to',
#   'the',
#   'playlist',
#   'called',
#   'heartland',
#   'country'],
#  ['the',
#   'spring',
#   'classical',
#   'playlist',
#   'needs',
#   'partners',
#   'in',
#   'crime',
#   'added',
#   'to',
#   'it',
#   '.'],
#  ['add',
#   'the',
#   'artist',
#   '<unk>',
#   '<unk>',
#   'to',
#   'the',
#   'conexiones',
#   'playlist'],
#  ['add',
#   'written',
#   'in',
#   'red',
#   'to',
#   'my',
#   'cleaning',
#   'the',
#   'house',
#   'playlist',
#   '.'],
#  ['add', 'album', 'to', 'feeling', 'blue'],
#  ['open',
#   'my',
#   'acoustic',
#   'concentration',
#   'playlist',
#   'and',
#   'play',
#   'an',
#   'entire',
#   'album'],
#  ['add', '<unk>', 'to', 'my', 'assassin', "'s", '<unk>'],
#  ['i',
#   'want',
#   'more',
#   'francis',
#   'healy',
#   'in',
#   'the',
#   'rockin',
#   "'",
#   'vibes',
#   'playlist',
#   '.'],
#  ['add', 'gareth', 'gates', 'to', 'my', 'autumn', 'playlist'],
#  ['add', 'tune', 'to', 'sxsw', 'fresh', 'playlist'],
#  ['add', 'track', 'to', 'todo', 'latino'],
#  ['add', 'to', 'my', 'verano', 'list', 'a', 'song', 'by', 'andy', 'lee'],
#  ['add', 'song', 'to', 'my', 'club', 'hits'],
#  ['add',
#   'this',
#   'tune',
#   'to',
#   'my',
#   'playlist',
#   'titled',
#   'uncharted',
#   'nathan',
#   'drake'],
#  ['add', '<unk>', 'te', '<unk>', 'to', 'the', 'hit', 'remix', 'playlist'],
#  ['put',
#   'this',
#   'album',
#   'into',
#   '<unk>',
#   "'s",
#   'infinite',
#   'indie',
#   'folk',
#   'playlist'],
#  ['add',
#   'yuna',
#   'ito',
#   'to',
#   'the',
#   'hot',
#   '<unk>',
#   '&',
#   'horror',
#   'shows',
#   'playlist',
#   '.'],
#  ['add', 'the', 'artist', 'ruby', 'to', 'my', 'digging', 'now', 'list'],
#  ['add',
#   'this',
#   'tune',
#   'to',
#   'my',
#   'it',
#   "'s",
#   'a',
#   'southern',
#   'thing',
#   'playlist'],
#  ['add',
#   'the',
#   'album',
#   'to',
#   'the',
#   'top',
#   'country',
#   'tracks',
#   'on',
#   'spotify',
#   'playlist',
#   '.'],
#  ['add',
#   'this',
#   'track',
#   'to',
#   'the',
#   'classical',
#   'music',
#   'for',
#   'smart',
#   'kids',
#   'playlist'],
#  ['add',
#   'an',
#   'album',
#   'to',
#   'corinne',
#   "'s",
#   'beast',
#   'mode',
#   'playlist',
#   '.'],
#  ['include', 'the', 'album', 'by', 'arthur', '<unk>', 'in', 'urban', 'poet'],
#  ['i',
#   'need',
#   'to',
#   'add',
#   'to',
#   'the',
#   'all',
#   'things',
#   'post',
#   'starting',
#   'with',
#   'my',
#   'favorites',
#   'from',
#   'the',
#   'silence'],
#  ['add', '<unk>', '<unk>', 'to', 'my', 'indie', 'mim', 'playlist'],
#  ['add', 'ernie', 'hawkins', 'to', 'the', 'dubstep', 'playlist', '.'],
#  ['add',
#   'the',
#   '<unk>',
#   '<unk>',
#   'alone',
#   'to',
#   'my',
#   'playlist',
#   'called',
#   'the',
#   'funny',
#   'thing',
#   'about',
#   'football',
#   'is'],
#  ['add', '<unk>', '<unk>', 'to', 'women', 'of', 'country', 'playlist'],
#  ['add', 'this', 'song', 'to', 'brooklyn', 'beat'],
#  ['add',
#   'anthony',
#   'hamilton',
#   'to',
#   'my',
#   'list',
#   'women',
#   'of',
#   'hip',
#   'hop'],
#  ['add',
#   'as',
#   'i',
#   'was',
#   'going',
#   'to',
#   'st',
#   '<unk>',
#   'to',
#   'the',
#   'fantasia',
#   'playlist',
#   '.'],
#  ['put', 'paula', 'abdul', 'on', 'musica', 'espanola'],
#  ['add',
#   'the',
#   'entity',
#   'por',
#   'una',
#   'cabeza',
#   'to',
#   'my',
#   'playlist',
#   'forever',
#   'alone'],
#  ['add', 'silver', '<unk>', 'to', 'teh', 'sin', '<unk>', 'playlist', '.'],
#  ['please',
#   'add',
#   'this',
#   'song',
#   'to',
#   'my',
#   'llegando',
#   'a',
#   'casa',
#   'palylist'],
#  ['add', 'the', 'song', 'to', 'the', 'martin', 'garrix', 'show', 'playlist'],
#  ['add',
#   'more',
#   'david',
#   'wolfenberger',
#   'to',
#   'my',
#   'duetos',
#   'playlist',
#   '.'],
#  ['i',
#   'want',
#   'to',
#   'add',
#   'club',
#   'mix',
#   'to',
#   'the',
#   'playlist',
#   'with',
#   'the',
#   'title',
#   'clasicos'],
#  ['add', 'eric', '<unk>', 'to', 'country', 'coffeehouse'],
#  ['add', '<unk>', '<unk>', 'to', 'my', 'us', 'latin', 'top', 'playlist'],
#  ['add', 'track', 's', 'smash', 'hits', 'to', 'my'],
#  ['add', 'this', 'album', 'to', 'my', 'blues', 'playlist'],
#  ['add', 'this', 'adam', 'clayton', 'tune', 'to', 'sxsw', 'fresh', 'playlist'],
#  ['add',
#   'this',
#   'teddy',
#   'charles',
#   'album',
#   'to',
#   'this',
#   'is',
#   'pavarotti',
#   'my',
#   'playlist'],
#  ['can',
#   'you',
#   'add',
#   'confessions',
#   'to',
#   'my',
#   'playlist',
#   'called',
#   'clasica'],
#  ['add', 'buddy', '<unk>', 'to', 'my', 'this', 'is', 'j', '<unk>', 'playlist'],
#  ['i',
#   'want',
#   'to',
#   'add',
#   'this',
#   'song',
#   'to',
#   'my',
#   'infantil',
#   'playlist'],
#  ['add', '<unk>', 'to', 'my', "'s", 'jam', '<unk>', 'playlist'],
#  ['add',
#   'a',
#   '<unk>',
#   'of',
#   'warped',
#   'music',
#   'ii',
#   'to',
#   'workout',
#   'twerkout',
#   'playlist'],
#  ['add',
#   'this',
#   'track',
#   'to',
#   'my',
#   'epic',
#   'wall',
#   'of',
#   'sound',
#   'playlist'],
#  ['add', 'michael', '<unk>', 'to', 'electronic', 'bliss'],
#  ['add', 'angela', 'au', 'to', 'the', 'playlist', 'radar', 'latino'],
#  ['add',
#   'artist',
#   '<unk>',
#   '<unk>',
#   '<unk>',
#   'to',
#   'my',
#   'conexiones',
#   'playlist'],
#  ['add', 'track', 'to', 'this', 'is', 'puccini'],
#  ['i',
#   'need',
#   'to',
#   'add',
#   'a',
#   'song',
#   'to',
#   'my',
#   'lo',
#   'que',
#   'suena',
#   'new',
#   'york',
#   'playlist',
#   '.'],
#  ['add', '<unk>', '<unk>', 'in', 'keys'],
#  ['add', 'alain', 'caron', 'to', 'my', 'travelling', 'playlist'],
#  ['add',
#   'the',
#   'r',
#   'l',
#   '<unk>',
#   'album',
#   'to',
#   'my',
#   'nothing',
#   'but',
#   'a',
#   'party',
#   'r',
#   '&',
#   'b',
#   'playlist'],
#  ['add', 'steve', 'jordan', 'to', '<unk>', "'s", 'tgif'],
#  ['add', 'to', 'my', 'playlist', 'all', 'funked', 'up', 'this', 'track'],
#  ['add', '<unk>', 'to', 'my', 'rockin', "'", 'vibes', 'playlist'],
#  ['add', 'billy', 'strayhorn', 'to', 'my', 'highway', 'playlist'],
#  ['add', '<unk>', 'on', 'to', 'halloween', 'teens'],
#  ['add', 'this', 'song', 'to', 'rock', 'party'],
#  ['i',
#   'want',
#   'to',
#   'add',
#   'lady',
#   '<unk>',
#   'to',
#   'my',
#   'playlist',
#   'lo',
#   'que',
#   'suena',
#   'new',
#   'york'],
#  ['i',
#   'want',
#   'to',
#   'add',
#   'an',
#   'album',
#   'to',
#   'noreen',
#   "'s",
#   'endorphin',
#   'rush',
#   'playlist',
#   '.'],
#  ['add',
#   'famous',
#   'to',
#   'my',
#   'playlist',
#   'lo',
#   'que',
#   'suena',
#   'new',
#   'york'],
#  ['add', '<unk>', 'to', 'queen', 'playlis'],
#  ['add', 'hold', 'my', '<unk>', 'to', 'electronow'],
#  ['add', 'tobias', '<unk>', 'to', 'my', 'bring', 'back', 'the', 's', 'list'],
#  ['add', 'jack', 'be', '<unk>', 'to', 'my', 'reggae', '<unk>', 'list'],
#  ['add', 'jan', '<unk>', 'in', 'endorphin', 'rush'],
#  ['add', '<unk>', 'to', 'my', 'ultra', 'metal', 'playlist'],
#  ['please',
#   'add',
#   'liberty',
#   'forever',
#   'to',
#   'the',
#   'road',
#   'trip',
#   'playlist',
#   '.'],
#  ['put',
#   'another',
#   'track',
#   'in',
#   'my',
#   'electronica',
#   '&',
#   'dance',
#   'playlist',
#   '.'],
#  ['add', 'the', 'tune', 'to', 'the', 'indie', 'workout', 'playlist'],
#  ['add',
#   'david',
#   'henry',
#   '<unk>',
#   'to',
#   'the',
#   'this',
#   'is',
#   'nicky',
#   'jam',
#   'playlist',
#   '.'],
#  ['add',
#   'this',
#   'jane',
#   '<unk>',
#   'track',
#   'to',
#   'my',
#   'the',
#   'sleep',
#   'machine',
#   'waterscapes'],
#  ['i', 'would', 'like', 'this', 'artist', 'on', 'drum', '&', 'breaks', '.'],
#  ['i',
#   "'d",
#   'like',
#   'to',
#   'add',
#   'the',
#   'artist',
#   '<unk>',
#   '<unk>',
#   'onto',
#   'my',
#   'fresh',
#   'electronic',
#   'playlist',
#   '.'],
#  ['add', '<unk>', 'in', 'concert', 'to', 'my', 'feel', 'good', 'dinner'],
#  ['add', 'harry', 'j', 'to', 'my', 'dubstep', 'dangles', 'dirty'],
#  ['add',
#   'partners',
#   'in',
#   'crime',
#   'to',
#   '<unk>',
#   "'s",
#   'lo',
#   'que',
#   'suena',
#   'los',
#   'angeles'],
#  ['add', 'this', 'song', 'onto', 'hip', 'hop', 'gaming', 'playlist'],
#  ['add',
#   'this',
#   'artist',
#   'to',
#   'my',
#   'this',
#   'is',
#   'philip',
#   'glass',
#   'playlist'],
#  ['i',
#   'want',
#   'to',
#   'put',
#   'look',
#   'to',
#   'you',
#   'on',
#   'the',
#   'playlist',
#   'named',
#   's',
#   'classic',
#   'hits'],
#  ['add', 'no', 'secrets', 'to', 'power', 'gaming', 'playlist'],
#  ['add', 'track', 'to', 'hit', 'remix'],
#  ['add', 'ali', 'lohan', 'songs', 'in', 'club', 'hits'],
#  ['add', 'this', 'tune', 'to', '<unk>', '<unk>'],
#  ['add', 'hold', 'tight', 'to', 'my', 'throwback', 'party'],
#  ['put',
#   'do',
#   'you',
#   'love',
#   'me',
#   'on',
#   'my',
#   'acoustic',
#   'soul',
#   'playlist'],
#  ['add',
#   'the',
#   'name',
#   'the',
#   'rd',
#   'world',
#   'to',
#   'the',
#   'playlist',
#   'rock',
#   'me',
#   'up'],
#  ['add',
#   'this',
#   'tune',
#   'to',
#   'my',
#   'playlist',
#   'named',
#   'women',
#   'of',
#   'fresh',
#   'finds'],
#  ['add', 'sammy', '<unk>', 'to', 'ultra', 'metal'],
#  ['add', '<unk>', 'to', 'the', 'deep', 'house', 'playlist'],
#  ['add',
#   'the',
#   'name',
#   'not',
#   '<unk>',
#   'away',
#   'to',
#   'the',
#   'playlist',
#   'the',
#   'midnight',
#   'hour'],
#  ['add',
#   '<unk>',
#   '<unk>',
#   'to',
#   'the',
#   'cafe',
#   'con',
#   'leche',
#   'playlist',
#   '.'],
#  ['place', 'this', 'tune', 'onto', 'my', 'dinner', 'for', 'playlist', '.'],
#  ['add', 'exit', 'to', 'i', 'love', 'my', "'s", 'rollerdisco', 'list'],
#  ['add', 'darkest', 'angels', 'to', 'my', 'sos'],
#  ['please',
#   'put',
#   'another',
#   'tune',
#   'into',
#   'the',
#   'laundry',
#   'playlist',
#   '.'],
#  ['add',
#   'global',
#   'underground',
#   '<unk>',
#   'to',
#   'my',
#   'best',
#   'metal',
#   'of',
#   'the',
#   'new',
#   'millennium'],
#  ['add',
#   'a',
#   'bill',
#   '<unk>',
#   'track',
#   'to',
#   'the',
#   'conexiones',
#   'playlist',
#   '.'],
#  ['add', 'j', 'j', '<unk>', 'to', 'my', 'heavy', 'gamer', 'playlist', '.'],
#  ['add',
#   'country',
#   'nights',
#   'by',
#   'a',
#   'journal',
#   'of',
#   'the',
#   'plague',
#   'year',
#   'to',
#   'playlist'],
#  ['add', 'nana', '<unk>', 'to', 'a', 'sudden', 'rainstorm'],
#  ['add',
#   '<unk>',
#   '<unk>',
#   'to',
#   'my',
#   'sweet',
#   'soul',
#   'chillout',
#   'playlist'],
#  ['i',
#   'want',
#   '<unk>',
#   'added',
#   'to',
#   'the',
#   'ntc',
#   'gym',
#   'strong',
#   'playlist'],
#  ['add', 'this', '<unk>', '<unk>', 'track', 'to', 'under', 'the', 'surface'],
#  ['add', '<unk>', '<unk>', 'to', 'the', 'relaxing', 'playlist', '.'],
#  ['add', '<unk>', '<unk>', 'to', 'my', 'soul', 'revived', 'list'],
#  ['add', 'artist', 'to', 'lo', 'mejor', 'de', 'los', "'s"],
#  ['this', 'track', 'should', 'go', 'on', 'my', 'evening', 'chill', 'playlist'],
#  ['add',
#   'a',
#   'mina',
#   'caputo',
#   'album',
#   'to',
#   'my',
#   'after',
#   'hours',
#   'party'],
#  ['put', 'frank', '<unk>', 'in', 'my', 'playlist', 'good', 'music'],
#  ['put',
#   'this',
#   'track',
#   'from',
#   'the',
#   'edge',
#   'on',
#   'my',
#   'funk',
#   'soul',
#   'disco',
#   'playlist'],
#  ['add',
#   'a',
#   '<unk>',
#   '<unk>',
#   'track',
#   'to',
#   'the',
#   'hip',
#   'hop',
#   'gaming',
#   'playlist',
#   '.'],
#  ['add', '<unk>', '<unk>', 'to', 'my', 'synth', 'pop'],
#  ['add', 'songs', 'in', "'s", 'hip', 'hop', 'of', 'artist'],
#  ['add', 'step', 'to', 'me', 'to', 'the', 'clasicos', 'playlist', '.'],
#  ['add', 'this', 'track', 'to', 'the', 'sunshine', 'reggae', 'playlist'],
#  ['add', 'de', '<unk>', '<unk>', 'to', 'my', 'domingo', 'indie', 'palylist'],
#  ['add', '<unk>', '<unk>', '<unk>', 'album', 'in', 'funky', 'jams'],
#  ['add', 'track', 'to', 'kickass', 'metal'],
#  ['add', 'song', 'to', 'my', 'pop', '<unk>'],
#  ['please',
#   'add',
#   '<unk>',
#   '<unk>',
#   'to',
#   'my',
#   'playlist',
#   'guest',
#   'list',
#   'polygon'],
#  ['add',
#   'this',
#   'tune',
#   'by',
#   'kurt',
#   'james',
#   'to',
#   'the',
#   'playlist',
#   'latin',
#   'pop',
#   'classics'],
#  ['add', '<unk>', 'album', 'to', 'my', '<unk>', 'total'],
#  ['add',
#   '<unk>',
#   '<unk>',
#   'repeat',
#   'to',
#   'classical',
#   'moments',
#   'in',
#   'movies'],
#  ['add',
#   'this',
#   'song',
#   'to',
#   'this',
#   'is',
#   'no',
#   'te',
#   'va',
#   '<unk>',
#   'playlist'],
#  ['add',
#   '<unk>',
#   '<unk>',
#   'to',
#   'leticia',
#   "'s",
#   'animal',
#   'humor',
#   'playlist'],
#  ['add', 'tune', 'to', '<unk>', 'weekly', 'pauline', '<unk>', 'playlist'],
#  ['add',
#   '<unk>',
#   'on',
#   'nothing',
#   'to',
#   'my',
#   '<unk>',
#   'and',
#   'the',
#   'city',
#   'playlist'],
#  ['add', '<unk>', '<unk>', 'smith', 'iv', 'to', 'blues', 'masters'],
#  ['add',
#   'an',
#   'album',
#   'in',
#   'my',
#   'playlist',
#   'in',
#   'the',
#   'name',
#   'of',
#   'blues'],
#  ['put', 'united', '<unk>', 'onto', 'my', 'rare', 'groove', 'playlist'],
#  ['add', 'lagaylia', 'frazier', 'to', 'my', 'emotron'],
#  ['add', 'a', 'shot', 'at', 'glory', 'to', 'calm', 'before', 'the', 'storm'],
#  ['add',
#   'this',
#   'artist',
#   'to',
#   'the',
#   'playlist',
#   'called',
#   'fusion',
#   'fest'],
#  ['add', 'song', 'to', 'my', 'mellow', 'beats', 'list'],
#  ['add',
#   'don',
#   'and',
#   'sherri',
#   'to',
#   'the',
#   'electrosafari',
#   'playlist',
#   '.'],
#  ['can',
#   'you',
#   'put',
#   'a',
#   'song',
#   'by',
#   'jessica',
#   '<unk>',
#   'on',
#   'my',
#   'playlist',
#   'entitled',
#   'a',
#   'sudden',
#   'rainstorm'],
#  ['add',
#   '<unk>',
#   'to',
#   'the',
#   'playlist',
#   'named',
#   'pre-party',
#   'r',
#   '&',
#   'b',
#   'jams'],
#  ['add', 'a', 'song', 'to', 'in', 'residence', 'metal', 'hammer', 'episode'],
#  ['add',
#   'the',
#   'stars',
#   'and',
#   '<unk>',
#   'forever',
#   'to',
#   'the',
#   'soulful',
#   'disco',
#   'playlist',
#   '.'],
#  ['add',
#   'beijing',
#   'huanying',
#   'ni',
#   'to',
#   'my',
#   'workday',
#   'lounge',
#   'playlist'],
#  ['add', 'how', 'to', 'sos', 'playlist'],
#  ['can',
#   'you',
#   'put',
#   'dj',
#   '<unk>',
#   '<unk>',
#   'onto',
#   'the',
#   'decade',
#   'playlist',
#   '?'],
#  ['add', 'fabri', 'fibra', 'to', 'evening', 'acoustic'],
#  ['add', 'this', 'tune', 'to', 'escapada'],
#  ['add',
#   'the',
#   '<unk>',
#   'to',
#   'marina',
#   "'s",
#   'playlist',
#   'it',
#   "'s",
#   'a',
#   'southern',
#   'thing'],
#  ['put',
#   'this',
#   'artist',
#   'into',
#   'my',
#   'found',
#   'them',
#   'first',
#   'playlist',
#   'please'],
#  ['add', 'stephen', '<unk>', 'to', 'confidence', 'boost'],
#  ['add', 'paul', 'franklin', 'to', 'my', 'the', 'bachelor', 'party'],
#  ['add', 'a', 'track', 'to', 'the', 'another', 'glass', 'playlist', '.'],
#  ['please',
#   'add',
#   'a',
#   'track',
#   'by',
#   'david',
#   '<unk>',
#   'to',
#   'my',
#   'workout',
#   'playlist',
#   '.'],
#  ['add', 'this', 'artist', 'to', 'my', 'feel', 'good', 'dinner', 'playlist'],
#  ['add',
#   '<unk>',
#   'to',
#   'my',
#   'mother',
#   "'s",
#   'primavera',
#   'sound',
#   'barcelona',
#   'playlist'],
#  ['add',
#   'an',
#   'album',
#   'by',
#   'cowboy',
#   'troy',
#   'to',
#   'my',
#   'piano',
#   'in',
#   'the',
#   'background',
#   'playlist',
#   '.'],
#  ['add',
#   '<unk>',
#   'and',
#   'the',
#   'north',
#   'to',
#   'my',
#   'hot',
#   'house',
#   'playlist',
#   '.'],
#  ['add',
#   'tour',
#   '<unk>',
#   '<unk>',
#   'en',
#   '<unk>',
#   'to',
#   'the',
#   'roadrunner',
#   'rec',
#   'new',
#   'releases',
#   'playlist',
#   '.'],
#  ['i',
#   'want',
#   'global',
#   'top',
#   'to',
#   'have',
#   '<unk>',
#   '<unk>',
#   'added',
#   'to',
#   'it',
#   '.'],
#  ['add',
#   'the',
#   'block',
#   '<unk>',
#   'welcome',
#   'to',
#   'the',
#   '<unk>',
#   'onto',
#   'my',
#   'cafe',
#   'con',
#   'leche',
#   'list'],
#  ['add', 'paul', 'wright', 'album', 'to', 's', 'smash', 'hits', 'playlist'],
#  ['add', 'an', 'artist', 'to', 'my', 'playlist', 'this', 'is', '<unk>'],
#  ['add',
#   'a',
#   'tune',
#   'to',
#   'the',
#   'this',
#   'is',
#   'animal',
#   'collective',
#   'playlist',
#   '.'],
#  ['add', 'this', '<unk>', '<unk>', 'tune', 'to', 'latin', 'party', 'anthems'],
#  ['add',
#   '<unk>',
#   '<unk>',
#   'to',
#   'my',
#   'throwback',
#   'thursday',
#   'playlist',
#   '.'],
#  ['add',
#   'the',
#   'album',
#   'by',
#   '<unk>',
#   'to',
#   'my',
#   'cloud',
#   'rap',
#   'playlist'],
#  ['add', '<unk>', 'ross', 'to', 'the', 'electrosafari', 'playlist'],
#  ['put',
#   '<unk>',
#   '<unk>',
#   'into',
#   'my',
#   'hillary',
#   'clinton',
#   "'s",
#   'women',
#   "'s",
#   'history',
#   'month',
#   'playlist',
#   '.'],
#  ['add',
#   'a',
#   'gate',
#   'through',
#   '<unk>',
#   'mirrors',
#   'to',
#   '<unk>',
#   "'",
#   'good',
#   'playlist'],
#  ['put',
#   'some',
#   'frank',
#   '<unk>',
#   'into',
#   'my',
#   'edna',
#   'st',
#   'vincent',
#   'millay',
#   'playlist',
#   '.'],
#  ['add', '<unk>', 'to', 'trap', 'land', 'playlist'],
#  ['add', '<unk>', 'chandler', 'to', 'my', 'aux', 'cord', 'privileges'],
#  ['put', 'kan', 'mikami', 'on', 'pre-party', 'r', '&', 'b', 'jams'],
#  ['add', 'let', 'the', 'season', 'in', 'to', 'my', 'lo-fi', 'love'],
#  ['add',
#   'be',
#   'yourself',
#   'tonight',
#   'to',
#   'i',
#   'love',
#   'my',
#   's',
#   'hip',
#   'hop'],
#  ['add',
#   'track',
#   'to',
#   'my',
#   'las',
#   'canciones',
#   'mas',
#   'lindas',
#   'del',
#   'mundo',
#   'playlist'],
#  ['add', 'this', 'roy', 'orbison', 'song', 'onto', 'women', 'of', 'comedy'],
#  ['add', 'artist', 'to', 'laundry'],
#  ['add', 'sara', '<unk>', 'to', 'my', 'targeted', 'list'],
#  ['add', 'jonathan', '<unk>', 'to', 'my', 'indie', 'electronics', 'playlist'],
#  ['add', 'track', 'to', 'my', 'cloud', 'rap'],
#  ['add', 'this', 'song', 'to', 'my', 'playlist', 'under', 'funky', 'jams'],
#  ['add',
#   'mary',
#   'wells',
#   'sings',
#   'my',
#   'guy',
#   'to',
#   'the',
#   'electro',
#   'sur',
#   'playlist',
#   '.'],
#  ['add', 'tune', 'to', 'soft', 'rock', 'playlist'],
#  ['add', '<unk>', '<unk>', 'to', 'my', 'running', 'power', 'playlist'],
#  ['i',
#   'want',
#   'a',
#   'song',
#   'by',
#   'john',
#   '<unk>',
#   'in',
#   'the',
#   'bajo',
#   'las',
#   'estrellas',
#   'playlist',
#   '.'],
#  ['add', '<unk>', '<unk>', 'to', 'my', 'this', 'is', 'nicky', 'jam'],
#  ['add',
#   'bossa',
#   'nova',
#   'soul',
#   'samba',
#   'to',
#   'my',
#   '<unk>',
#   '<unk>',
#   'rhythm',
#   '&',
#   'blues',
#   'playlist'],
#  ['add', 'brad', 'kane', 'to', 'the', '<unk>', 'iron', 'soundtrack', '.'],
#  ['please', 'add', 'this', 'song', 'to', 'indiespain', 'list'],
#  ['add', 'this', 'artist', 'to', 'dubstep'],
#  ['add', 'song', 'to', 'siesta'],
#  ['put', 'sarah', '<unk>', 'onto', 'my', 'the', 'metalsucks', 'playlist'],
#  ['i',
#   'want',
#   'another',
#   'track',
#   'added',
#   'to',
#   'the',
#   'korean',
#   'osts',
#   'playlist',
#   '.'],
#  ['add', 'cream', 'to', 'the', 'funk', 'playlist', '.'],
#  ['add',
#   'take',
#   'me',
#   'back',
#   'to',
#   'dear',
#   'old',
#   '<unk>',
#   'to',
#   'my',
#   'dinner',
#   'playlist'],
#  ['add',
#   'this',
#   'tune',
#   'to',
#   'the',
#   'deep',
#   'dark',
#   'indie',
#   'folk',
#   'playlist'],
#  ['add', 'this', '<unk>', 'song', 'to', 'my', 'dancehall', 'official'],
#  ['add',
#   '<unk>',
#   'de',
#   'melody',
#   'nelson',
#   'to',
#   'my',
#   "'s",
#   'baby',
#   'makers',
#   'playlist'],
#  ['add', 'this', 'tune', 'to', 'my', 'road', 'trip', 'playlist'],
#  ['add', 'album', 'to', 'ultra', 'metal'],
#  ['i', "'d", 'like', 'to', 'add', 'this', 'album', 'to', 'funtime', '.'],
#  ['add', 'tune', 'to', 'punk', 'espanol'],
#  ['i',
#   'want',
#   'to',
#   'add',
#   'in',
#   'the',
#   'mood',
#   'to',
#   'my',
#   'playlist',
#   'called',
#   'my',
#   'folksy',
#   'love'],
#  ['put',
#   'this',
#   'jerry',
#   'dixon',
#   'song',
#   'onto',
#   'my',
#   'tokyo',
#   'rising',
#   'playlist',
#   '.'],
#  ['add', 'jennie', ',', 'jennie', 'to', 'my', 'metal', 'playlist'],
#  ['add', 'dias', '<unk>', 'to', 'my', 'todo', 'reggaeton', 'playlist'],
#  ['add', 'us', '<unk>', 'to', 'my', 'new', 'boots'],
#  ['add',
#   'this',
#   'track',
#   'by',
#   'clem',
#   'burke',
#   'to',
#   'my',
#   'atmospheric',
#   'black',
#   'metal',
#   'playlist'],
#  ['add', '<unk>', 'to', 'the', 'de', 'manhattan', 'con', 'amor', 'playlist'],
#  ['add',
#   'the',
#   '<unk>',
#   '<unk>',
#   'song',
#   'to',
#   'my',
#   'the',
#   'martin',
#   'garrix',
#   'show',
#   'playlist',
#   '.'],
#  ['add', 'artist', 'to', 'playlist', 'epic', 'gaming'],
#  ['add', 'robin', 's', 'to', 'sxsw', 'latin'],
#  ['add', 'olympia', 'to', 'from', 'the', 'delta', 'to', 'chicago'],
#  ['the', 'enamorandose', 'playlist', 'needs', 'another', 'album', '.'],
#  ['add', 'song', 'to', '<unk>', 'playlist'],
#  ['add', '<unk>', 'to', 'disco', 'fever', 'track'],
#  ['i',
#   "'d",
#   'like',
#   'to',
#   'add',
#   'this',
#   'album',
#   'to',
#   'my',
#   'siesta',
#   'playlist'],
#  ['add', 'kevin', 'cadogan', 'to', 'the', 's', 'classic', 'hits', 'list'],
#  ['add', 'the', 'artist', 'to', 'my', 'spooning', 'playlist'],
#  ['add',
#   'this',
#   'alan',
#   'wilson',
#   'track',
#   'to',
#   'my',
#   'this',
#   'is',
#   'luis',
#   'fonsi',
#   'playlist'],
#  ['for',
#   'my',
#   'playlist',
#   'wild',
#   'country',
#   'add',
#   'a',
#   'great',
#   'day',
#   'for',
#   'freedom'],
#  ['add', 'ricky', 'nelson', 'to', 'my', 'classical', 'x', 'playist'],
#  ['add', 'track', 'to', 'my', 'playlist', 'a', 'sudden', 'rainstorm'],
#  ['add',
#   '<unk>',
#   'james',
#   'dio',
#   'tune',
#   'to',
#   'women',
#   'of',
#   'electronic',
#   'selection'],
#  ['include', 'pat', '<unk>', 'on', 'guest', 'list', 'engadget'],
#  ['add',
#   'this',
#   'track',
#   'to',
#   'my',
#   'this',
#   'is',
#   'thomas',
#   'rhett',
#   'playlist'],
#  ['add',
#   'i',
#   'hate',
#   'myself',
#   'and',
#   'i',
#   'want',
#   'to',
#   'die',
#   'to',
#   'my',
#   'six',
#   'string',
#   'peacefulness'],
#  ['add', 'yuna', 'ito', 'to', 'my', 'cena', 'elegante', 'playlist'],
#  ['please',
#   'add',
#   '<unk>',
#   'anthony',
#   'to',
#   'my',
#   'playlist',
#   'this',
#   'is',
#   'mozart'],
#  ['put', '<unk>', 'on', 'the', 'top', 'classical', 'playlist'],
#  ['the', 'get', 'going', 'playlist', 'needs', 'another', 'song', '.'],
#  ['add',
#   '<unk>',
#   'the',
#   'tale',
#   'to',
#   'my',
#   'playlist',
#   'called',
#   'adrenaline',
#   'workout'],
#  ['put',
#   'molly',
#   'and',
#   '<unk>',
#   'in',
#   'the',
#   'french',
#   'n',
#   "'",
#   'heavy',
#   'playlist',
#   '.'],
#  ['add',
#   'an',
#   'album',
#   'by',
#   '<unk>',
#   'to',
#   'my',
#   'classic',
#   'country',
#   'playlist'],
#  ['add', 'the', '<unk>', '<unk>', 'to', 'crate', 'diggers', 'anonymous'],
#  ['add', '<unk>', '<unk>', 'to', 'my', 'romantic', 'evening', 'playlist'],
#  ['add',
#   'the',
#   '<unk>',
#   'tune',
#   'yesterday',
#   'to',
#   'my',
#   'playlist',
#   ',',
#   'the',
#   'southern',
#   'highway',
#   'chronicles'],
#  ['add', '<unk>', 'song', 'in', 'grime', 'instrumentals'],
#  ['add', 'koichi', '<unk>', 'to', 'whm'],
#  ['put', '<unk>', 'into', 'my', 'summer', 'playlist'],
#  ['add',
#   'little',
#   '<unk>',
#   'and',
#   'the',
#   'lady',
#   '<unk>',
#   'to',
#   '<unk>',
#   "'s",
#   'punk',
#   'rock',
#   'workout',
#   'playlist'],
#  ['i',
#   "'d",
#   'like',
#   'to',
#   'add',
#   'this',
#   'tune',
#   'to',
#   'my',
#   'spotify',
#   'orchestra',
#   'cello',
#   'playlist'],
#  ['add',
#   'this',
#   'michael',
#   'v',
#   'track',
#   'to',
#   'my',
#   'folk',
#   '&',
#   'americana'],
#  ['add',
#   '<unk>',
#   'driven',
#   'engine',
#   '&',
#   '<unk>',
#   'letha',
#   "'s",
#   'all',
#   'things',
#   'post'],
#  ['add', 'nana', '<unk>', 'to', 'my', 'modern', '<unk>', 'playlist'],
#  ['add', 'the', 'artist', 'to', 'the', 'latin', 'jazz', 'playlist', '.'],
#  ['put', '<unk>', 'in', 'my', 'canadian', 'country', 'playlist'],
#  ['add',
#   'another',
#   'tune',
#   'to',
#   'my',
#   'songs',
#   'for',
#   'you',
#   ',',
#   'not',
#   'your',
#   'parents',
#   'playlist',
#   '.'],
#  ['add', '<unk>', 'to', '<unk>', "'s", 'brooklyn', 'beat', 'playlist'],
#  ['<unk>', 'rock', 'me', 'up', 'song', 'to', 'my', 'list'],
#  ['add',
#   'some',
#   '<unk>',
#   '<unk>',
#   'to',
#   'my',
#   'original',
#   'columbia',
#   '<unk>',
#   'list'],
#  ['add',
#   'the',
#   'name',
#   'the',
#   'song',
#   'about',
#   'the',
#   '<unk>',
#   'to',
#   'playlist',
#   'piano',
#   'in',
#   'the',
#   'background'],
#  ['add', 'rock', '&', 'roll', 'to', 'my', 'playlist', 'named', 'night', 'out'],
#  ['add', '<unk>', '<unk>', 'to', 'my', 'power', 'gaming', 'playlist'],
#  ['put', 'this', 'song', 'on', 'the', 'chips', 'and', 'salsa', 'playlist'],
#  ['add', 'to', 'my', 'mac', "'n", 'cheese', 'playlist', 'with', '<unk>'],
#  ['add',
#   'country',
#   'favorites',
#   'willie',
#   'nelson',
#   'style',
#   'to',
#   'my',
#   'playlist',
#   'titled',
#   'spinnin',
#   "'",
#   'records',
#   'top'],
#  ['i',
#   'want',
#   'harris',
#   'to',
#   'be',
#   'added',
#   'to',
#   'my',
#   'latin',
#   'dance',
#   'cardio',
#   'playlist'],
#  ['i',
#   'would',
#   'like',
#   'to',
#   'add',
#   'something',
#   'by',
#   '<unk>',
#   '<unk>',
#   'to',
#   'my',
#   'hip',
#   'hop',
#   'new',
#   'school',
#   'playlist'],
#  ['shawn',
#   'lane',
#   'should',
#   'be',
#   'moved',
#   'to',
#   'my',
#   'cena',
#   'con',
#   'amigos',
#   'playlist'],
#  ['add', 'dave', '<unk>', 'to', 'my', 'acoustic', 'blues', 'playlist'],
#  ['add', 'this', 'track', 'to', 'the', 'playlist', 'named', 'cali', 'fire'],
#  ['put',
#   'the',
#   'artist',
#   'pat',
#   '<unk>',
#   'onto',
#   'the',
#   'emily',
#   'dickinson',
#   'playlist',
#   '.'],
#  ['add', '<unk>', 'hotel', 'to', 'my', 'verano', 'forever'],
#  ['add',
#   'this',
#   'song',
#   'to',
#   'my',
#   'novedades',
#   'viernes',
#   'sudamerica',
#   'playlist'],
#  ['add',
#   'a',
#   'song',
#   'by',
#   '<unk>',
#   'nazeri',
#   'to',
#   'my',
#   'playlist',
#   'called',
#   'this',
#   'is',
#   'jennifer',
#   'lopez'],
#  ['add', 'this', 'track', 'to', 'new', 'hip', 'hop'],
#  ['add', 'this', 'is', 'status', 'quo', 'to', 'teddy', 'riley'],
#  ['add',
#   'the',
#   'outlaw',
#   'blues',
#   'to',
#   'the',
#   'playlist',
#   'with',
#   'the',
#   'title',
#   'top',
#   'country',
#   'tracks',
#   'on',
#   'spotify'],
#  ['add',
#   'bring',
#   'back',
#   'my',
#   'daddy',
#   'to',
#   'me',
#   'to',
#   'my',
#   'playlist',
#   'named',
#   'might',
#   'and',
#   'myth',
#   'power',
#   'metal'],
#  ['add', '<unk>', 'to', 'the', 'african', 'heat', 'playlist', '.'],
#  ['add', '<unk>', 'to', '<unk>', "'s", 'hands', 'up'],
#  ['i',
#   'want',
#   'to',
#   'add',
#   'kool',
#   'keith',
#   'to',
#   'my',
#   'chill',
#   'out',
#   'dinner',
#   'playlist'],
#  ['add', 'david', '<unk>', 'to', 'my', 'futuros', 'hits', 'list'],
#  ['add', 'artist', 'to', 'my', 'endorphin', 'rush', 'playlist'],
#  ['add', 'current', 'album', 'to', 'my', 'pop', 'gaming', 'playlist'],
#  ['i',
#   'want',
#   'if',
#   'i',
#   'could',
#   'be',
#   'with',
#   'you',
#   'added',
#   'to',
#   'mellow',
#   'dinner'],
#  ['add', 'spanish', 'castle', 'magic', 'to', 'daily', 'lift'],
#  ['add', 'little', 'walter', 'to', 'women', 'of', 'comedy', 'playlist'],
#  ['add', 'this', 'karina', 'album', 'to', 'my', 'folk', 'pop', 'playlist'],
#  ['add',
#   'a',
#   'tune',
#   'by',
#   'louis',
#   '<unk>',
#   '<unk>',
#   'to',
#   'my',
#   'cleaning',
#   'playlist'],
#  ['please',
#   'add',
#   'a',
#   'tune',
#   'by',
#   'kaori',
#   'utatsuki',
#   'to',
#   'my',
#   'korean',
#   'osts',
#   'playlist'],
#  ['add', 'om', 'to', 'my', 'classic', 'punk'],
#  ['add',
#   'this',
#   'jimmy',
#   'london',
#   'tune',
#   'to',
#   'the',
#   'new',
#   'waltz',
#   'playlist'],
#  ['add', 'bill', 'evans', 'to', 'the', '<unk>', 'mix', 'playlist', '.'],
#  ['add', 'ray', '<unk>', 'to', 'my', 'chill', 'vibes', 'playlist', '.'],
#  ['add', 'this', 'track', 'to', 'latin', 'jazz'],
#  ['add', 'this', 'artist', 'to', '<unk>', "'s", 'fresh', 'finds'],
#  ['add', '<unk>', '<unk>', 'to', 'my', 'guitar', 'hero', 'live', 'playlist'],
#  ['add', 'this', 'tune', 'to', 'my', 'wine', '&', 'dine', 'playlist'],
#  ['add', 'this', 'tune', 'to', 'my', 'rage', 'radio', 'playlist'],
#  ['add', 'bad', 'news', 'to', 'highway', 'playlist'],
#  ['put',
#   'this',
#   'tune',
#   'on',
#   'my',
#   'playlist',
#   '<unk>',
#   '&',
#   '<unk>',
#   'death',
#   'metal'],
#  ['add',
#   'the',
#   'singer',
#   'barbara',
#   'to',
#   'my',
#   'country',
#   'radio',
#   'playlists'],
#  ['add',
#   '<unk>',
#   '<unk>',
#   'in',
#   'my',
#   'playlist',
#   'called',
#   '<unk>',
#   '&',
#   '<unk>'],
#  ['add', '<unk>', 'in', 'my', 'pre-party', 'list'],
#  ['put', 'this', 'artist', 'on', 'domingo', 'indie'],
#  ['add', 'ian', 'north', 'to', 'my', 'autumn', 'lounge', 'playlist'],
#  ['add', 'this', 'tune', 'to', 'the', 'leche', 'con', 'chocolate', 'playlist'],
#  ['add', 'to', 'the', 'rock', 'games'],
#  ['i',
#   'want',
#   'to',
#   'add',
#   'something',
#   'by',
#   'the',
#   'artist',
#   'nadine',
#   'to',
#   'my',
#   'workday',
#   '-',
#   'pop',
#   'playlist'],
#  ['add',
#   '<unk>',
#   '<unk>',
#   '<unk>',
#   '<unk>',
#   'to',
#   'my',
#   'women',
#   'of',
#   'metal',
#   'playlist'],
#  ['add', 'album', 'to', 'my', 'classical', 'essentials', 'playlist'],
#  ['add', 'teenager', 'to', 'the', 'queen', 'playlist'],
#  ['please', 'put', 'this', 'artist', 'on', 'my', 'indie', 'mim', 'playlist'],
#  ['add', 'artist', 'steve', '<unk>', 'to', 'rhythm', 'and', 'blues'],
#  ['add', 'dean', 'martin', 'track', 'to', 'metal', 'xplorer', 'playlist'],
#  ['put', 'this', 'song', 'in', 'the', 'playlist', 'trap', 'land'],
#  ['add',
#   'natsu',
#   'natsu',
#   '<unk>',
#   '<unk>',
#   'to',
#   'my',
#   'rock',
#   'classics',
#   'playlist'],
#  ['add', '<unk>', 'to', 'my', 'this', 'is', 'prince', 'playlist'],
#  ['add', 'this', 'tune', 'to', 'my', 'list', 'jazz', 'vibes'],
#  ['add', '<unk>', '<unk>', 'to', 'my', 'rockabilly', 'mania', 'playlist', '.'],
#  ['add', 'this', 'album', 'to', 'my', 'all', 'out', 's', 'playlist'],
#  ['add', 'song', 'to', 'zen', 'focus', 'playlist'],
#  ['add',
#   'the',
#   'da',
#   'brat',
#   'track',
#   'to',
#   'the',
#   '<unk>',
#   'up',
#   'the',
#   'sun',
#   'playlist',
#   '.'],
#  ['add', 'roger', '<unk>', 'to', 'punk', 'rock', 'workout'],
#  ['add',
#   'francesco',
#   'de',
#   'gregori',
#   'to',
#   '<unk>',
#   "'s",
#   'women',
#   'who',
#   'dj',
#   'playlist'],
#  ['add', 'sarah', '<unk>', 'to', 'the', 'spa', 'treatment', 'playlist', '.'],
#  ['add',
#   'third',
#   'stone',
#   'from',
#   'the',
#   'sun',
#   'to',
#   'the',
#   'concentracion',
#   'playlist',
#   '.'],
#  ['i',
#   'want',
#   'to',
#   'add',
#   'aprite',
#   'le',
#   'finestre',
#   'to',
#   'my',
#   'playlist',
#   'entitled',
#   'this',
#   'is',
#   'earth',
#   ',',
#   'wind',
#   '&',
#   'fire'],
#  ['add', '<unk>', 'to', 'women', 'of', 'classical'],
#  ['add', 'this', 'album', 'to', 'my', 'throwback', 'party', 'playlist'],
#  ['add', 'nina', '<unk>', 'to', 'essential', 'folk'],
#  ['please',
#   'add',
#   'secrets',
#   'of',
#   'the',
#   '<unk>',
#   'to',
#   'the',
#   'playlist',
#   'called',
#   'keep',
#   'calm'],
#  ['add', 'karin', 'dreijer', 'andersson', 'in', 'escapada', 'album'],
#  ['add',
#   'this',
#   'ruth',
#   '<unk>',
#   'seeger',
#   'song',
#   'to',
#   'my',
#   'playlist',
#   'called',
#   'the',
#   'soundtrack'],
#  ['add', 'jenifer', 'to', 'rock', 'the', "'s"],
#  ['add',
#   'the',
#   'big',
#   'mama',
#   'thornton',
#   'song',
#   'to',
#   'cassie',
#   "'s",
#   'punk',
#   'rock',
#   'workout',
#   'playlist'],
#  ['add', 'artist', 'to', 'acoustic', 'soul'],
#  ['add',
#   'name',
#   'house',
#   'of',
#   'gold',
#   'to',
#   'the',
#   'de',
#   'manhattan',
#   'con',
#   'amor',
#   'playlist'],
#  ['add', 'the', 'song', 'to', 'my', 'we', 'everywhere', 'playlist'],
#  ['can',
#   'you',
#   'add',
#   'this',
#   'tune',
#   'to',
#   'the',
#   'night',
#   'out',
#   'playlist',
#   '?'],
#  ['add', 'album', 'to', 'my', 'party', 'with', 'friends'],
#  ['add', 'i', 'roy', 'to', 'my', 'this', 'is', 'rosana', 'playlist'],
#  ['add', '<unk>', 'to', 'my', 'found', 'them', 'first'],
#  ['the',
#   'songs',
#   'to',
#   'sing',
#   'in',
#   'the',
#   'car',
#   'playlist',
#   'needs',
#   'k',
#   'j',
#   '<unk>',
#   'discography',
#   'in',
#   'it',
#   '.'],
#  ['add',
#   '<unk>',
#   'to',
#   'the',
#   'rhythm',
#   'to',
#   'the',
#   'playlist',
#   'massive',
#   'soca',
#   'hits'],
#  ['add', '<unk>', 'and', 'sacrifice', 'to', 'skatepark', 'punks'],
#  ['for',
#   'my',
#   'playlist',
#   'it',
#   "'s",
#   'ok',
#   'to',
#   'like',
#   'jazz',
#   'add',
#   'this',
#   'tune'],
#  ['add', '<unk>', 'waits', 'to', 'my', 'picnic', 'in', 'the', 'park'],
#  ['can',
#   'you',
#   'please',
#   'put',
#   'this',
#   'track',
#   'onto',
#   'my',
#   'todo',
#   'novedades',
#   'playlist',
#   '?'],
#  ['add',
#   'totally',
#   'stress',
#   'free',
#   'by',
#   'bobby',
#   'lord',
#   'to',
#   'my',
#   'playlist'],
#  ['add',
#   'shame',
#   'on',
#   'you',
#   'to',
#   'my',
#   'masters',
#   'of',
#   'metal',
#   'playlist'],
#  ['add', 'cake', 'to', 'bake', 'to', 'lo', 'que', 'suena', 'new', 'york'],
#  ['add', 'this', 'song', 'to', 'the', 'novedades', 'pop', 'playlist'],
#  ['add',
#   'something',
#   'by',
#   '<unk>',
#   'cobb',
#   'to',
#   'my',
#   'la',
#   'mejor',
#   'musica',
#   'para',
#   'tus',
#   'fiestas',
#   'playlist'],
#  ['add', 'young', '<unk>', 'to', 'club', 'hits'],
#  ['put', 'this', 'artist', 'on', 'my', 'folk', 'for', 'kids', 'playlist'],
#  ['add', 'this', 'track', 'to', 'duetos'],
#  ['add', 'the', 'album', 'to', '<unk>', "'s", '<unk>', 'playlist', '.'],
#  ['i',
#   'want',
#   'to',
#   'add',
#   'another',
#   'album',
#   'to',
#   'the',
#   'wine',
#   '&',
#   'dine',
#   'playlist',
#   '.'],
#  ['add', 'artist', 'to', 'novedades', 'pop'],
#  ['add',
#   'please',
#   ',',
#   'please',
#   ',',
#   'please',
#   ',',
#   'let',
#   'me',
#   'get',
#   'what',
#   'i',
#   'want',
#   'to',
#   'my',
#   'crate',
#   'diggers',
#   'anonymous'],
#  ['go', 'to', 'cali', 'fire', 'and', 'add', '<unk>', 'to', 'my', 'playlist'],
#  ['add', '<unk>', 'brother', '<unk>', 'to', 'love', 'moments'],
#  ['add', 'a', 'tune', 'in', 'women', 'of', 'classical'],
#  ['add', '<unk>', 'to', 'my', 'gold', 'edition', 'playlist'],
#  ['add',
#   'this',
#   'track',
#   'to',
#   'anne',
#   "'s",
#   'playlist',
#   'named',
#   'just',
#   'smile'],
#  ['i',
#   "'d",
#   'like',
#   'a',
#   'new',
#   'england',
#   'added',
#   'to',
#   'classical',
#   'moments',
#   'in',
#   'movies',
#   '.'],
#  ['i',
#   'want',
#   'to',
#   'add',
#   'robin',
#   'hood',
#   'and',
#   'queen',
#   '<unk>',
#   'to',
#   'my',
#   'playlist',
#   'entitled',
#   'genuine',
#   'r',
#   '&',
#   'b'],
#  ['ad',
#   'i',
#   'should',
#   'have',
#   '<unk>',
#   'better',
#   'to',
#   'this',
#   'is',
#   'bb',
#   'king'],
#  ['add',
#   'i',
#   '<unk>',
#   'of',
#   'a',
#   'dragon',
#   'to',
#   'my',
#   'futuros',
#   'hits',
#   'playlist',
#   '.'],
#  ['add',
#   'hello',
#   'central',
#   ',',
#   'give',
#   'me',
#   'heaven',
#   'to',
#   'indie',
#   'pop'],
#  ['add',
#   'twin',
#   '<unk>',
#   'fire',
#   'walk',
#   'with',
#   'me',
#   'to',
#   'the',
#   'night',
#   'out',
#   'playlist'],
#  ['add', 'another', 'artist', 'to', 'my', 'soul', 'bpm', 'playlist'],
#  ['add',
#   'el',
#   '<unk>',
#   'de',
#   'la',
#   '<unk>',
#   'to',
#   'the',
#   'new',
#   'waltz',
#   'playlist'],
#  ['add',
#   'matthew',
#   '<unk>',
#   'artist',
#   'in',
#   'showstopper',
#   'being',
#   'mary',
#   'jane'],
#  ['add',
#   '<unk>',
#   '<unk>',
#   'to',
#   'my',
#   'uncharted',
#   'nathan',
#   'drake',
#   'playlist'],
#  ['add', 'house', 'of', '<unk>', 'to', 'my', 's', 'indie', 'playlist'],
#  ['add', 'tune', 'to', 'my', 'playlist', 'ironing'],
#  ['add',
#   'out',
#   'of',
#   'the',
#   'air',
#   'to',
#   'my',
#   'a',
#   'mis',
#   'ninos',
#   'de',
#   'playlist'],
#  ['add', 'this', 'artist', 'to', 'sleep', 'tight'],
#  ['can',
#   'you',
#   'add',
#   'something',
#   'by',
#   'snow',
#   'onto',
#   'my',
#   'zen',
#   'focus',
#   'playlist'],
#  ['can',
#   'i',
#   'put',
#   'johnny',
#   'burke',
#   'onto',
#   'my',
#   'lo',
#   'que',
#   'suena',
#   'los',
#   'angeles',
#   'playlist',
#   '?'],
#  ['add', 'the', 'rd', 'world', 'to', 'my', 'focus', 'now'],
#  ['add', 'eric', '<unk>', 'to', 'women', 'of', 'jazz'],
#  ['add', 'a', 'track', 'to', 'fusion', 'fest'],
#  ['add', 'this', '<unk>', 'play', 'to', 'women', "'s", 'lit', 'playlist'],
#  ['please',
#   'add',
#   'this',
#   'album',
#   'to',
#   'the',
#   'playlist',
#   'titled',
#   'hip',
#   'hop',
#   'new',
#   'school'],
#  ['add', 'a', 'track', 'in', '<unk>', 'running', '<unk>', 'mix'],
#  ['put',
#   'this',
#   'song',
#   'by',
#   '<unk>',
#   'on',
#   'my',
#   'all',
#   'out',
#   's',
#   'playlist'],
#  ['add', 'album', 'to', 'my', 'grandes', 'unplugged'],
#  ['can',
#   'you',
#   'put',
#   'a',
#   'song',
#   'by',
#   'rick',
#   '<unk>',
#   'on',
#   'my',
#   'hot',
#   'playlist'],
#  ['put', 'ron', '<unk>', 'on', 'my', 'disco', 'fever', 'playlist'],
#  ['add', '<unk>', '<unk>', 'to', 'la', 'mejor', 'musica', 'dance'],
#  ['add', 'roots', 'of', 'the', '<unk>', 'to', 'blues', 'roots'],
#  ['put', 'bring', 'me', 'down', 'onto', 'my', 'tokyo', 'rising', 'playlist'],
#  ['add', 'artist', 'leonard', 'cohen', 'to', 'my', 'indie', '<unk>'],
#  ['add',
#   'a',
#   '<unk>',
#   'jean',
#   'tune',
#   'to',
#   'the',
#   'soul',
#   'revived',
#   'playlist',
#   '.'],
#  ['add', 'this', 'song', 'to', 'wedding', 'classics', 'playlist'],
#  ['add',
#   'this',
#   'song',
#   'to',
#   'my',
#   'roadrunner',
#   'rec',
#   'new',
#   'releases',
#   'list',
#   '.'],
#  ['can',
#   'you',
#   'add',
#   'something',
#   'from',
#   '<unk>',
#   'man',
#   'to',
#   'my',
#   'this',
#   'is',
#   'mozart',
#   'playlist'],
#  ['put', '<unk>', 'on', 'my', 'dias', 'de', 'frio', 'playlist'],
#  ['add',
#   'the',
#   'current',
#   'artist',
#   'to',
#   'my',
#   'top',
#   'pop',
#   'tracks',
#   'on',
#   'spotify',
#   'playlist'],
#  ['add', 'jack', 'scott', 'to', 'my', 'fantasia', 'playlist'],
#  ['please',
#   'put',
#   'book',
#   'of',
#   'love',
#   'on',
#   'my',
#   'ntc',
#   'high',
#   'intensity',
#   'training',
#   'tracks',
#   'playlist'],
#  ['add',
#   'a',
#   'billy',
#   'strayhorn',
#   'song',
#   'to',
#   'my',
#   'the',
#   'selektor',
#   'playlist'],
#  ['add', 'tune', 'to', 'my', 'relax', '&', '<unk>', 'playlist'],
#  ['add', 'stephanie', 'biddle', 'to', 'my', 'digster', 'reggae', 'playlist'],
#  ['add',
#   'song',
#   'by',
#   'ian',
#   'mcdonald',
#   'to',
#   'an',
#   'instrumental',
#   'sunday'],
#  ['put', 'this', 'track', 'on', 'soul', 'bpm', 'my', 'playlist'],
#  ['add',
#   'people',
#   'take',
#   '<unk>',
#   'of',
#   'each',
#   'other',
#   'to',
#   'rhythm',
#   'and',
#   'blues',
#   'playlist'],
#  ['add',
#   'the',
#   'song',
#   'do',
#   "n't",
#   'drink',
#   'the',
#   'water',
#   'to',
#   'my',
#   'playlist'],
#  ['add', 'git', 'to', 'domingo', 'indie'],
#  ['add',
#   '<unk>',
#   'newest',
#   'track',
#   'to',
#   'my',
#   'i',
#   'love',
#   'my',
#   '``',
#   's',
#   'r',
#   '&',
#   'b',
#   'playlist'],
#  ['find',
#   'lesley',
#   "'s",
#   'epic',
#   'classical',
#   'playlist',
#   'and',
#   'add',
#   'this',
#   'tune'],
#  ['please',
#   'add',
#   'the',
#   'song',
#   'by',
#   '<unk>',
#   '<unk>',
#   'to',
#   'my',
#   'pre-party',
#   'r',
#   '&',
#   'b',
#   'jams',
#   'list'],
#  ['add', 'this', 'is', '<unk>', '<unk>', 'by', 'milk'],
#  ['add',
#   'come',
#   'on',
#   'feel',
#   'the',
#   '<unk>',
#   'to',
#   'my',
#   'salsa',
#   'classics',
#   'playlist',
#   '.'],
#  ['this',
#   'track',
#   'should',
#   'go',
#   'into',
#   'my',
#   'playlist',
#   'called',
#   'this',
#   'is',
#   'beethoven'],
#  ['add', 'live', 'around', 'the', 'world', 'to', 'crossroad', 'blues'],
#  ['put',
#   'a',
#   'xiang',
#   'xiang',
#   'track',
#   'onto',
#   'women',
#   'of',
#   'the',
#   'blues'],
#  ['can',
#   'you',
#   'add',
#   'a',
#   'tune',
#   'by',
#   'natalie',
#   'macmaster',
#   'to',
#   'my',
#   'viajes',
#   'playlist'],
#  ['add', 'kansas', 'city', ',', 'missouri', 'to', 'stress', 'relief'],
#  ['add',
#   '<unk>',
#   '<unk>',
#   'los',
#   '<unk>',
#   'to',
#   'my',
#   'amor',
#   'amor',
#   'playlist'],
#  ['add',
#   '<unk>',
#   '<unk>',
#   'to',
#   'my',
#   'chillin',
#   "'",
#   'on',
#   'a',
#   'dirt',
#   'road',
#   'playlist'],
#  ['add', 'artist', 'to', 'ina', "'s", 's', 'smash', 'hits'],
#  ['add', 'another', 'song', 'to', 'the', 'acoustic', 'soul', 'playlist'],
#  ['put',
#   '<unk>',
#   'g',
#   'don',
#   'gorilla',
#   'on',
#   'my',
#   'classical',
#   'romance',
#   'playlist'],
#  ['i',
#   "'d",
#   'like',
#   'for',
#   'you',
#   'to',
#   'put',
#   'this',
#   'artist',
#   'to',
#   'my',
#   'evening',
#   'commute',
#   'playlist',
#   '.'],
#  ['add', 'tune', 'to', 'reggae', 'infusions'],
#  ['my',
#   'indietronic',
#   'playlist',
#   'needs',
#   'until',
#   'the',
#   'end',
#   'of',
#   'time',
#   'added'],
#  ['add', 'the', 'current', 'tune', 'to', 'my', 'rock', 'gaming', 'playlist'],
#  ['add', 'lisa', 'to', 'my', 'playlist', 'street', 'dance'],
#  ['add', 'album', 'to', 'mellow', 'bars'],
#  ['add', 'an', 'album', 'to', 'my', 'list', 'clasicos', 'de', '<unk>'],
#  ['the',
#   'feel',
#   'good',
#   'indie',
#   'rock',
#   'playlist',
#   'needs',
#   'another',
#   'song'],
#  ['add',
#   'barry',
#   'mcguire',
#   'to',
#   'my',
#   'playlist',
#   'called',
#   'have',
#   'a',
#   '<unk>',
#   '.'],
#  ['add', 'tune', 'papa', '<unk>', 'to', 'exitos', 'espana', 'playlist'],
#  ['add',
#   'the',
#   'track',
#   'by',
#   '<unk>',
#   '<unk>',
#   'to',
#   'the',
#   'this',
#   'is',
#   'luis',
#   'fonsi',
#   'playlist'],
#  ['can', 'you', 'add', 'don', '<unk>', 'to', 'my', 'pop', 'playlist', '?'],
#  ['please',
#   'put',
#   'this',
#   'artist',
#   'into',
#   'my',
#   'lo',
#   'mejor',
#   'de',
#   'radio',
#   'playlist'],
#  ['i',
#   'want',
#   'to',
#   'put',
#   'land',
#   'of',
#   'the',
#   'dead',
#   'into',
#   'my',
#   'big',
#   'daddy',
#   "'s",
#   'booze',
#   '&',
#   'blues',
#   'playlist',
#   '.'],
#  ['add', '<unk>', 'to', 'noctambulo', 'playlist'],
#  ['add', 'warm', 'and', 'beautiful', 'to', 'the', 'ironing', 'playlist', '.'],
#  ['add',
#   'this',
#   'track',
#   'to',
#   'my',
#   'lo',
#   'que',
#   'suena',
#   'new',
#   'york',
#   'playlist'],
#  ['put', 'track', 'on', 'my', 'synth', 'pop', 'list'],
#  ['add', '<unk>', '<unk>', 'to', 'my', 'political', 'punks', 'playlist'],
#  ['please',
#   'put',
#   'this',
#   'track',
#   'onto',
#   'letha',
#   "'s",
#   'signed',
#   'xoxo',
#   'playlist'],
#  ['add', 'this', 'album', 'to', 'my', 'us', 'latin', 'top', 'palylist'],
#  ['add',
#   'shake',
#   'your',
#   '<unk>',
#   'to',
#   'my',
#   'concentracion',
#   'indie',
#   'rock',
#   'playlist'],
#  ['add', 'arthur', 'lee', 'to', 'my', 'jazz', 'vibes', 'playlist'],
#  ['include', '<unk>', 'in', 'pre-party', 'r', '&', 'b', 'jams'],
#  ['i',
#   'want',
#   'my',
#   'reggae',
#   'infusions',
#   'playlist',
#   'to',
#   'have',
#   '<unk>',
#   '<unk>',
#   'on',
#   'it',
#   '.'],
#  ['add', 'artist', 'to', 'playlist', 'classic', 'punk'],
#  ['add',
#   'this',
#   'album',
#   'to',
#   'holly',
#   "'s",
#   'bandas',
#   'sonoras',
#   'playlist'],
#  ['add', 'song', 'by', '<unk>', '<unk>', 'to', 'hit', 'rewind'],
#  ['add',
#   'this',
#   'tune',
#   'to',
#   'the',
#   'spinnin',
#   "'",
#   'records',
#   'top',
#   'list'],
#  ['add', 'album', 'to', 'my', 'deathcore', 'playlist'],
#  ['put',
#   'targeted',
#   'in',
#   'my',
#   'clapton',
#   'chronicles',
#   'the',
#   'best',
#   'of',
#   'eric',
#   'clapton',
#   'playlist',
#   '.'],
#  ['add',
#   'this',
#   'song',
#   'to',
#   'my',
#   'classical',
#   'dance',
#   'music',
#   '<unk>',
#   '&',
#   'beyond',
#   'list'],
#  ['add',
#   'when',
#   'you',
#   'come',
#   'back',
#   'to',
#   'the',
#   'jazz',
#   'for',
#   'loving',
#   'couples',
#   'playlist',
#   '.'],
#  ['add', 'a', 'track', 'to', 'summer', 'of', 'love'],
#  ['add',
#   'josefina',
#   '<unk>',
#   'to',
#   '<unk>',
#   "'s",
#   'guest',
#   'list',
#   'gamesradar',
#   'playlist'],
#  ['add', 'i', "'m", 'only', 'a', 'man', 'to', 'my', 'flow', 'espanol'],
#  ['add', 'an', 'album', 'by', 'jenifer', 'to', 'my', 'travelling', 'playlist'],
#  ['add',
#   'heat',
#   'of',
#   'the',
#   'night',
#   'to',
#   'my',
#   'novedades',
#   'viernes',
#   'sudamerica',
#   'playlist'],
#  ['add', 'artist', 'to', 'my', '<unk>', 'playlist'],
#  ['put', 'this', 'song', 'in', 'my', 'funk', 'playlist', ',', 'please'],
#  ['add',
#   'aprite',
#   'le',
#   'finestre',
#   'to',
#   'my',
#   'this',
#   'is',
#   'earth',
#   ',',
#   'wind',
#   '&',
#   'fire',
#   'playlist'],
#  ['put',
#   'the',
#   'joy',
#   'division',
#   'the',
#   'complete',
#   '<unk>',
#   'recordings',
#   'on',
#   'hits'],
#  ['please',
#   'put',
#   '<unk>',
#   '<unk>',
#   "'s",
#   'song',
#   'onto',
#   'operacion',
#   'bikini',
#   '.'],
#  ['can',
#   'you',
#   'add',
#   'a',
#   '<unk>',
#   '<unk>',
#   'album',
#   'to',
#   'my',
#   'tgif',
#   'playlist'],
#  ['add',
#   'the',
#   '<unk>',
#   '<unk>',
#   'onto',
#   'the',
#   'playlist',
#   'called',
#   'party',
#   'through',
#   'the',
#   'decades'],
#  ['add',
#   'joey',
#   'fatone',
#   'to',
#   'my',
#   'spotlight',
#   'on',
#   'country',
#   'playlist'],
#  ['add', 'the', 'tune', 'to', 'bandas', 'sonoras'],
#  ['add',
#   'first',
#   'issue',
#   'to',
#   'my',
#   'your',
#   'favorite',
#   '<unk>',
#   'playlist'],
# ...
#   '<unk>',
#   'to',
#   '<unk>',
#   "'s",
#   'lo',
#   'mejor',
#   'de',
#   'radio',
#   'playlist',
#   '.'],
#  ['add', 'devil', '<unk>', 'to', 'my', 'party', 'list'],
#  ['add', 'ivan', 'mane', '<unk>', 'to', 'fusion', 'fest'],
#  ['add',
#   'a',
#   'jacob',
#   'miller',
#   'album',
#   'to',
#   'my',
#   'hardcore',
#   'punk',
#   'playlist',
#   '.'],
#  ['add', 'jamaica', 'say', 'you', 'will', 'to', 'my', 'metal'],
#  ['add', 'shooter', '<unk>', 'to', 'the', 'all', 'out', 's', 'playlist', '.'],
#  ['the',
#   'sleep',
#   'machine',
#   'rainforest',
#   'playlist',
#   'needs',
#   'another',
#   'tune'],
#  ['add', 'joan', '<unk>', 'to', 'running', 'playlist'],
#  ['add', '<unk>', '&', '<unk>', 'to', 'sin', 'ti', 'playlist'],
#  ['add',
#   'sara',
#   'carter',
#   'to',
#   'my',
#   'nothing',
#   'but',
#   'a',
#   'party',
#   'r',
#   '&',
#   'b'],
#  ['i',
#   'want',
#   '<unk>',
#   'on',
#   'a',
#   '<unk>',
#   'added',
#   'to',
#   'the',
#   'playlist',
#   'called',
#   'gold',
#   'edition'],
#  ['add', 'count', '<unk>', '<unk>', '<unk>', 'to', 'jazzy', 'romance'],
#  ['please',
#   'add',
#   'this',
#   'rex',
#   'griffin',
#   'tune',
#   'to',
#   'the',
#   'steampunk',
#   'playlist'],
#  ['<unk>',
#   '<unk>',
#   'rex',
#   'should',
#   'get',
#   'added',
#   'to',
#   'my',
#   'women',
#   'of',
#   'sxsw',
#   'playlist'],
#  ['add',
#   'this',
#   'album',
#   'by',
#   'don',
#   'reno',
#   'to',
#   'my',
#   'playlist',
#   'named',
#   'indiespain'],
#  ['for',
#   'my',
#   '<unk>',
#   'playlist',
#   'add',
#   'the',
#   'soul',
#   'sessions',
#   'volume'],
#  ['add',
#   'camille',
#   'to',
#   'the',
#   'this',
#   'is',
#   'lady',
#   'antebellum',
#   'playlist'],
#  ['add', '<unk>', 'to', 'extreme', 'metal', 'workout'],
#  ['add', 'sirusho', 'to', 'the', 'clasicos', 'playlist'],
#  ['add', 'tune', 'to', 'my', 'instrumental', 'funk', 'playlist'],
#  ['add',
#   'artist',
#   'chris',
#   '<unk>',
#   'to',
#   'my',
#   'the',
#   'birth',
#   'of',
#   'cool',
#   'playlist'],
#  ['put',
#   'some',
#   'mac',
#   '<unk>',
#   'in',
#   'my',
#   'latino',
#   'caliente',
#   'playlist',
#   '.'],
#  ['i',
#   'wish',
#   'to',
#   'add',
#   'this',
#   'album',
#   'to',
#   'the',
#   'dinner',
#   'playlist'],
#  ['add', 'family', 'tree', 'to', 'conexiones'],
#  ['add', 'the', 'tune', 'to', 'my', 'chill', 'hits', 'playlist', '.'],
#  ['add',
#   '<unk>',
#   'to',
#   'the',
#   'black',
#   'sabbath',
#   'the',
#   'dio',
#   'years',
#   'playlist'],
#  ['add',
#   '<unk>',
#   '<unk>',
#   'til',
#   '<unk>',
#   'to',
#   'my',
#   'this',
#   'is',
#   'trey',
#   'songz',
#   'playlist'],
#  ['add', 'this', 'tune', 'to', 'my', 'indie', 'reflection', 'playlist'],
#  ['i',
#   'want',
#   'a',
#   'mi',
#   'lu',
#   'bing',
#   'song',
#   'in',
#   'my',
#   'pop',
#   'dance',
#   'playlist',
#   '.'],
#  ['add', '<unk>', 'the', '<unk>', 'to', 'my', 'dubstep', 'playlist'],
#  ['add', 'what', 'if', 'punk', 'never', '<unk>', 'to', 'autumn'],
#  ['add', 'novedades', 'pop', 'to', 'my', 'all', 'out', 'of', 'luck', 'list'],
#  ['add', 'troy', 'van', '<unk>', 'to', 'my', 'nu', 'metal', 'list'],
#  ['add', 'this', 'tune', 'to', 'my', 'rock', 'this'],
#  ['add', 'impossible', 'is', 'nothing', 'to', 'spa', 'treatment'],
#  ['add', 'a', 'tune', 'to', '<unk>', '<unk>', "'", 'training', 'mix'],
#  ['add', 'a', 'track', 'to', 'my', 'playlist', 'funk', '<unk>', 'here'],
#  ['add', '<unk>', '<unk>', 'to', 'this', 'is', 'puccini'],
#  ['add',
#   'chrome',
#   'reflection',
#   'to',
#   'my',
#   'throwback',
#   'thursday',
#   'playlist'],
#  ['add', 'a', 'song', 'to', 'the', 'para', '<unk>', 'playlist', '.'],
#  ['add',
#   '<unk>',
#   '<unk>',
#   'to',
#   'my',
#   'great',
#   'female',
#   'voices',
#   'playlist',
#   '.'],
#  ['put', 'ron', 'wood', 'in', 'the', 'digster', 'reggae', 'playlist', '.'],
#  ['add', 'album', 'to', '<unk>', 'indie'],
#  ['add',
#   '<unk>',
#   'johnson',
#   'to',
#   'my',
#   'rock',
#   'save',
#   'the',
#   'queen',
#   'playlist'],
#  ['add', 'this', 'song', 'to', 'year', 'in', 'metal'],
#  ['add',
#   'this',
#   'album',
#   'to',
#   'my',
#   'de',
#   'camino',
#   'a',
#   'clase',
#   'playlist'],
#  ['can',
#   'you',
#   'put',
#   'some',
#   '<unk>',
#   'on',
#   'my',
#   'disco',
#   'fever',
#   'playlist'],
#  ['please', 'add', 'this', 'song', 'to', 'madden', 'nfl'],
#  ['add',
#   '<unk>',
#   'c',
#   '``',
#   'jethro',
#   '<unk>',
#   'burns',
#   'songs',
#   'in',
#   'my',
#   'playlist',
#   'soundscapes',
#   'for',
#   'gaming'],
#  ['add', 'a', 'j', '<unk>', 'to', 'rock', 'to', 'work'],
#  ['add', 'the', 'song', 'to', 'the', 'pure', '<unk>', 'playlists'],
#  ['add',
#   'this',
#   'track',
#   'by',
#   'brian',
#   '<unk>',
#   'to',
#   'the',
#   'spring',
#   'music',
#   'playlist'],
#  ['add',
#   'artist',
#   '<unk>',
#   '<unk>',
#   'to',
#   'my',
#   'old',
#   'school',
#   'death',
#   'metal',
#   'playlist'],
#  ['i',
#   "'d",
#   'like',
#   'to',
#   'move',
#   'the',
#   'artist',
#   'named',
#   'matt',
#   'walker',
#   'to',
#   'the',
#   'playlist',
#   'grandes',
#   'unplugged'],
#  ['add',
#   'every',
#   'song',
#   'is',
#   'a',
#   'cry',
#   'for',
#   'love',
#   'to',
#   'my',
#   'playlist',
#   'soul',
#   "'n",
#   "'",
#   'the',
#   'city'],
#  ['please',
#   'add',
#   'john',
#   '<unk>',
#   'to',
#   'the',
#   'funtime',
#   'activity',
#   'playlist'],
#  ['add',
#   'star',
#   'light',
#   ',',
#   'star',
#   'bright',
#   'to',
#   'my',
#   'jazz',
#   'classics',
#   'playlist',
#   '.'],
#  ['edit', 'classic', 'road', 'trip', 'songs', 'put', 'on', 'sammy', 'cahn'],
#  ['add', '<unk>', 'y', '<unk>', 'in', 'classic', 'jazz', 'funk'],
#  ['add',
#   'this',
#   'song',
#   'by',
#   '<unk>',
#   'to',
#   'my',
#   'sing',
#   'along',
#   'playlist'],
#  ['add', '<unk>', 'volume', 'in', 'all', 'out', 's', 'playlist'],
#  ['add', 'artist', 'to', 'my', "'s", 'party'],
#  ['add', 'a', 'tune', 'to', 'my', 'playlist', 'women', 'of', 'k-pop'],
#  ['add', 'album', 'to', 'my', 'i', 'love', 'my', "'s", 'r', '&', 'b'],
#  ['add', 'tune', 'to', 'my', 'folk', 'music', 'at', 'the', 'gaslight', 'cafe'],
#  ['add',
#   'heart',
#   'like',
#   'a',
#   'hurricane',
#   'to',
#   'digster',
#   'soul',
#   'classics'],
#  ['add',
#   'fish',
#   '<unk>',
#   'to',
#   'my',
#   'i',
#   'love',
#   'my',
#   '``',
#   's',
#   'r',
#   '&',
#   'b',
#   'playlist'],
#  ['put', 'this', 'album', 'on', 'my', 'road', 'trip', 'playlist'],
#  ['add', 'hotter', 'than', 'hell', 'to', 'my', 'fiesta', 'playlist'],
#  ['add',
#   'mike',
#   '<unk>',
#   'onto',
#   'my',
#   'crate',
#   'diggers',
#   'anonymous',
#   'playlist'],
#  ['add',
#   'david',
#   'dallas',
#   'to',
#   'my',
#   'latin',
#   'dance',
#   'cardio',
#   'playlist'],
#  ['add', 'this', 'artist', 'to', 'pop', 'picks'],
#  ['add',
#   '<unk>',
#   'to',
#   'my',
#   'this',
#   'is',
#   'zeze',
#   'di',
#   'camargo',
#   '&',
#   'luciano'],
#  ['add', 'my', 'album', 'to', 'this', 'is', 'al', 'green'],
#  ['add', 'this', 'artist', 'to', 'blues', 'roots', 'list'],
#  ['add',
#   'the',
#   'artist',
#   'to',
#   'the',
#   'nuclear',
#   'blast',
#   'novelties',
#   'playlist',
#   '.'],
#  ['add', 'born', 'free', 'to', 'fresh', 'r', '&', 'b'],
#  ['put',
#   'this',
#   'song',
#   'on',
#   'my',
#   'playlist',
#   ',',
#   'in',
#   'the',
#   'name',
#   'of',
#   'blues',
#   '.'],
#  ['add',
#   'the',
#   'artist',
#   'jamie',
#   't',
#   'to',
#   '<unk>',
#   "'s",
#   'winter',
#   'music',
#   'playlist'],
#  ['put', 'more', '<unk>', 'in', 'my', 'grandes', 'unplugged', 'playlist', '.'],
#  ['add', 'this', 'artist', 'to', 'my', 'classic', 'punk', 'playlist'],
#  ['the',
#   'sleep',
#   'machine',
#   'waterscapes',
#   'playlist',
#   'needs',
#   'some',
#   '<unk>',
#   '<unk>',
#   '<unk>',
#   'in',
#   'it',
#   '.'],
#  ['add',
#   'something',
#   'by',
#   '<unk>',
#   '<unk>',
#   'to',
#   'my',
#   'playlist',
#   'virales',
#   'de',
#   'siempre'],
#  ['add', 'the', '<unk>', 'album', 'to', 'cierra', 'la', 'puerta', 'playlist'],
#  ['add', 'the', 'tune', 'to', 'my', 'epic', 'classical', 'playlist', '.'],
#  ['add',
#   'this',
#   'tune',
#   'by',
#   'rod',
#   '<unk>',
#   'to',
#   '<unk>',
#   'alternativa',
#   'playlist'],
#  ['add', 'my', 'very', 'best', 'to', 'my', 'road', 'trip', 'playlist', '.'],
#  ['for',
#   'my',
#   'playlist',
#   'fresh',
#   'finds',
#   'hiptronix',
#   'add',
#   'the',
#   'name',
#   '<unk>',
#   'medley'],
#  ['rate', 'tune', 'to', 'my', 'natalie', 'macmaster', 'viajes'],
#  ['put',
#   'a',
#   'paul',
#   '<unk>',
#   'song',
#   'in',
#   'my',
#   'classic',
#   'jazz',
#   'funk',
#   'playlist',
#   '.'],
#  ['can',
#   'you',
#   'add',
#   'an',
#   'album',
#   'to',
#   'my',
#   'are',
#   '&',
#   'be',
#   'playlist'],
#  ['i',
#   'want',
#   'to',
#   'put',
#   'a',
#   'copy',
#   'of',
#   'this',
#   'tune',
#   'into',
#   'skatepark',
#   'punks'],
#  ['add', 'this', 'track', 'by', 'horace', 'andy', 'to', 'acoustic', 'soul'],
#  ['please',
#   'put',
#   'this',
#   'song',
#   'by',
#   '<unk>',
#   'in',
#   'my',
#   'hype',
#   'playlist'],
#  ['add',
#   'the',
#   'song',
#   'by',
#   'brian',
#   'larsen',
#   'to',
#   'the',
#   'cardio',
#   'playlist'],
#  ['add', 'cross', 'bones', 'style', 'to', 'guest', 'list', 'take'],
#  ['for',
#   'the',
#   'playlist',
#   'this',
#   'is',
#   'mozart',
#   'add',
#   'nana',
#   '<unk>',
#   'live',
#   '<unk>',
#   '<unk>',
#   'x',
#   'red',
#   '<unk>'],
#  ['add', 'the', '<unk>', 'singles', 'to', 'my', 'teen', 'party'],
#  ['add', 'the', 'artist', '<unk>', 'to', 'the', 'soul', 'revived', 'playlist'],
#  ['i',
#   'want',
#   'to',
#   'add',
#   'no',
#   'mystery',
#   'to',
#   '<unk>',
#   "'s",
#   'acoustic',
#   'love',
#   'playlist'],
#  ['add', 'this', 'artist', 'to', 'my', 'sinfonia', 'hipster'],
#  ['add', 'this', 'album', 'to', 'digster', 'future', 'hits'],
#  ['add', '<unk>', '<unk>', 'to', 'piano', 'chill'],
#  ['add', 'buddy', '<unk>', 'to', 'just', 'dance', 'by', 'aftercluv', 'list'],
#  ['add', 'barbara', 'to', 'the', 'metal', 'xplorer', 'playlist', '.'],
#  ['i',
#   'want',
#   'jimmie',
#   '<unk>',
#   'on',
#   'the',
#   'playlist',
#   'titled',
#   'lo',
#   'mejor',
#   'de',
#   'los',
#   "'s"],
#  ['add', 'song', 'to', 'thrash', 'attack'],
#  ['can',
#   'you',
#   'put',
#   'this',
#   '<unk>',
#   'song',
#   'onto',
#   'my',
#   'chill',
#   'playlist',
#   '?'],
#  ['add',
#   'falling',
#   'upstairs',
#   'to',
#   'the',
#   'playlist',
#   'named',
#   'chill',
#   'out'],
#  ['can',
#   'you',
#   'add',
#   'some',
#   'tommie',
#   'sunshine',
#   'to',
#   'my',
#   'chill',
#   'out',
#   'playlist'],
#  ['add',
#   'waltz',
#   'for',
#   '<unk>',
#   'to',
#   'my',
#   'soft',
#   'pop',
#   'hits',
#   'playlist',
#   '.'],
#  ['add',
#   'tunnel',
#   'of',
#   'love',
#   'to',
#   '<unk>',
#   "'s",
#   'metal',
#   'crash',
#   'course',
#   'palylist'],
#  ['add', 'tune', 'to', 'my', 'metal', 'crash', 'course', 'playlist'],
#  ['add',
#   'this',
#   'tune',
#   'by',
#   '<unk>',
#   'the',
#   'n',
#   '<unk>',
#   'to',
#   'my',
#   'this',
#   'is',
#   'bb',
#   'king',
#   'playlist'],
#  ['add',
#   'this',
#   'peter',
#   '<unk>',
#   'album',
#   'to',
#   'my',
#   'ntc',
#   'gym',
#   'strong'],
#  ['add',
#   'a',
#   'new',
#   '<unk>',
#   'for',
#   'mon',
#   'beau',
#   '<unk>',
#   'in',
#   '<unk>',
#   "'s",
#   'musica',
#   'libre',
#   'playlist'],
#  ['can',
#   'the',
#   'artist',
#   'big',
#   'mama',
#   'thornton',
#   'be',
#   'put',
#   'onto',
#   'my',
#   'trabajo',
#   'relax',
#   'playlist',
#   '?'],
#  ['add', 'this', 'track', 'to', 'my', 'dinnertime', 'acoustics', 'playist'],
#  ['put',
#   'this',
#   'track',
#   'on',
#   'the',
#   'playlist',
#   'with',
#   'the',
#   'name',
#   'roadrunner',
#   'rec',
#   'new',
#   'releases'],
#  ['ad', '<unk>', '<unk>', 'tune', 'to', 'my', 'pura', 'vida'],
#  ['i',
#   'want',
#   'to',
#   'put',
#   'this',
#   'song',
#   'in',
#   'my',
#   'new',
#   'boots',
#   'playlist'],
#  ['put', 'no', 'mystery', 'into', 'my', 'punk', 'essentials', 'playlist', '.'],
#  ['i',
#   'want',
#   'to',
#   'send',
#   'music',
#   'to',
#   'ann',
#   "'s",
#   'lists',
#   'from',
#   'sir',
#   'john',
#   'winston',
#   'ono',
#   'lennon',
#   ',',
#   'put',
#   'it',
#   'on',
#   'her',
#   'infinite',
#   'indie',
#   'folk',
#   'list'],
#  ['add', '<unk>', 'berlin', 'to', 'my', '<unk>'],
#  ['add', 'gary', '<unk>', 'to', 'the', 'power', 'gaming', 'playlist', '.'],
#  ['please',
#   'add',
#   's',
#   'classic',
#   'hits',
#   'asking',
#   'for',
#   'it',
#   'to',
#   'my',
#   'playlist'],
#  ['add', 'artist', 'my', 'laundry', 'playlist'],
#  ['add',
#   'billy',
#   'martin',
#   'album',
#   'to',
#   'my',
#   'legendary',
#   'guitar',
#   'solos',
#   'playlist'],
#  ['add', 'this', 'song', 'to', 'my', 'southern', 'gothic', 'playlist'],
#  ['add', '<unk>', '<unk>', 'to', 'my', 'bachelor', 'party', 'playlist', '.'],
#  ['add',
#   'track',
#   'by',
#   'fleetwood',
#   'mac',
#   'to',
#   'lakeisha',
#   "'s",
#   'playlist',
#   'todo',
#   'novedades'],
#  ['add', 'see', 'me', 'now', 'to', 'my', 'enamorandose', 'playlist'],
#  ['add',
#   'the',
#   'artist',
#   'a',
#   'j',
#   '<unk>',
#   'to',
#   'my',
#   'country',
#   'gold',
#   'playlist'],
#  ['add', '<unk>', 'to', 'my', 'wine', '&', 'dine', 'playlist', '.'],
#  ['add', 'the', 'artist', 'to', 'my', '<unk>', 'playlist'],
#  ['can',
#   'you',
#   'add',
#   'woman',
#   'of',
#   'the',
#   'world',
#   'to',
#   'my',
#   'playlist',
#   'entitled',
#   'duetos'],
#  ['add', 'this', 'track', 'to', 'my', 'global', 'funk'],
#  ['put',
#   'a',
#   'gary',
#   'clark',
#   'song',
#   'into',
#   'the',
#   'soul',
#   'bpm',
#   'playlist',
#   '.'],
#  ['add',
#   'something',
#   'so',
#   'right',
#   'to',
#   '<unk>',
#   "'s",
#   's',
#   'classic',
#   'hits',
#   'playlist'],
#  ['put',
#   'this',
#   '<unk>',
#   '<unk>',
#   'tune',
#   'on',
#   'my',
#   'alternative',
#   'route',
#   'playlist'],
#  ['add', '<unk>', '<unk>', 'to', 'workday', 'lounge'],
#  ['add', 'this', 'track', 'to', 'my', 'gold', 'school', 'playlist'],
#  ['add',
#   'petar',
#   '<unk>',
#   '<unk>',
#   'song',
#   'to',
#   'my',
#   'push',
#   'button',
#   'funk',
#   'playlist'],
#  ['add',
#   'a',
#   'song',
#   'by',
#   '<unk>',
#   'y',
#   'creek',
#   'to',
#   'my',
#   'spring',
#   'music'],
#  ['put', 'kan', 'on', 'my', 'indie', 'rock', 'road', 'trip'],
#  ['add',
#   'this',
#   'artist',
#   'named',
#   'kirk',
#   'hammett',
#   'to',
#   'my',
#   'playlist',
#   'los',
#   'radio',
#   'exitos'],
#  ['add',
#   'give',
#   'us',
#   'rest',
#   'to',
#   'my',
#   'very',
#   'nearly',
#   'nashville',
#   'playlist'],
#  ['put', 'deep', 'purple', 'on', 'this', 'is', 'jennifer', 'lopez'],
#  ['add',
#   'the',
#   'track',
#   'to',
#   'the',
#   'best',
#   'metal',
#   'of',
#   'the',
#   'new',
#   'millennium',
#   'playlist',
#   '.'],
#  ['add', 'this', 'song', 'to', 'country', 'coffeehouse'],
#  ['add', '<unk>', 'im', '<unk>', 'to', 'this', 'is', 'maxwell'],
#  ['add',
#   'rodriguez',
#   'artist',
#   'to',
#   'my',
#   'mujeres',
#   'y',
#   'hombres',
#   'y',
#   'fiesta',
#   'playlist'],
#  ['add', 'the', '<unk>', 'album', 'to', 'my', 'romantic', 'evening', 'album'],
#  ['add', 'the', 'album', 'to', 'the', 'metalcore', 'playlist'],
#  ['add',
#   'the',
#   'artist',
#   '<unk>',
#   'g',
#   '<unk>',
#   '<unk>',
#   'to',
#   'my',
#   'billboard',
#   'latin',
#   'music',
#   'awards',
#   '<unk>',
#   'playlist'],
#  ['put', 'four', 'in', 'blue', 'onto', 'ultimate', 's', '.'],
#  ['add', '<unk>', 'to', 'electro', 'latino'],
#  ['add', 'song', 'to', 'this', 'is', 'philip', 'glass'],
#  ['add', 'manos', '<unk>', 'to', 'lo', 'mejor', 'de', 'los', "'s"],
#  ['add', '<unk>', '<unk>', 'to', 'new', 'metal', 'tracks'],
#  ['put',
#   '<unk>',
#   'you',
#   'in',
#   'my',
#   'spotify',
#   'orchestra',
#   'cello',
#   'playlist',
#   '.'],
#  ['please',
#   'add',
#   '<unk>',
#   'to',
#   'my',
#   'irish',
#   'folk',
#   '-',
#   'jigs',
#   '&',
#   'reels',
#   'playlist'],
#  ['add', 'this', 'track', 'to', 'my', 'zen', 'focus', 'playlist'],
#  ['add', 'the', 'album', 'to', 'my', 'latin', 'pop', 'rising', 'playlist'],
#  ['add', 'image', 'to', 'the', 'nuclear', 'blast', 'novelties', 'playlist'],
#  ['add',
#   '<unk>',
#   'k',
#   '<unk>',
#   'k',
#   '<unk>',
#   '<unk>',
#   '<unk>',
#   'to',
#   '<unk>',
#   "'s",
#   'playlist',
#   'pura',
#   'vida'],
#  ['add', 'tune', 'to', 'this', 'is', 'trey', 'songz'],
#  ['add', 'sam', '<unk>', 'music', 'to', 'my', 'tgif', 'playlist'],
#  ['add', 'post', '<unk>', 'to', 'my', 'timeless', 'love', 'songs', 'playlist'],
#  ['add', 'the', 'maid', 'of', '<unk>', 'to', 'my', 's', 'smash', 'hits'],
#  ['add',
#   'one',
#   'good',
#   'reason',
#   'to',
#   'the',
#   'bachelor',
#   'party',
#   'playlist'],
#  ['add', 'joe', '<unk>', 'to', 'my', 'jazz', '-', 'classical', '<unk>'],
#  ['add', 'if', 'you', 'were', 'mine', 'to', 'classic', 'punk', 'playlist'],
#  ['add',
#   'the',
#   'green',
#   'book',
#   'in',
#   'my',
#   'playlist',
#   'mellowed',
#   'out',
#   'gaming'],
#  ['add', '<unk>', '<unk>', 'to', 'my', 'indie', 'mim', 'playlist', '.'],
#  ['add', 'the', 'tune', 'to', 'my', 'jazz', 'vibes', 'playlist'],
#  ['add',
#   'el',
#   '<unk>',
#   'del',
#   '<unk>',
#   'to',
#   'my',
#   'working',
#   'day',
#   'playlist'],
#  ['add', '<unk>', 'the', 'well', 'to', 'my', 'epic', 'wall', 'of', 'sound'],
#  ['add',
#   'another',
#   'tune',
#   'to',
#   'kristine',
#   "'s",
#   'laundry',
#   'playlist',
#   '.'],
#  ...]

# %%
def n_gram_fun(sentences , n):
    n_grams = {}
    for se in sentences:
        se = ["<s>"] * (n-1) + se + ["</s>"]
        se = tuple(se)
        for i in range(len(se)):
            gram = se[i:i+n]

            if gram in n_grams:         
                n_grams[gram] += 1
            else:      
                n_grams[gram] = 1
    return n_grams


print(n_gram_fun(full_q ,2))
#print(n_gram_fun([['add', 'another', 'song', 'to', 'the', 'cita', 'romantica', 'playlist', '.']] , 1))
#p(y|x) = c(x y )/c(x)
#p(another | add) = c(add another)
# Out:
# {('<s>', 'add'): 1243, ('add', 'another'): 19, ('another', 'song'): 10, ('song', 'to'): 99, ('to', 'the'): 310, ('the', '<unk>'): 634, ('<unk>', 'romantica'): 1, ('romantica', 'playlist'): 3, ('playlist', '.'): 254, ('.', '</s>'): 1958, ('</s>',): 11784, ('add', 'clem'): 1, ('clem', 'burke'): 2, ('burke', 'in'): 1, ('in', 'my'): 63, ('my', 'playlist'): 125, ('playlist', 'pre-party'): 1, ('pre-party', 'r'): 6, ('r', '&'): 22, ('&', 'b'): 33, ('b', 'jams'): 6, ('jams', '</s>'): 7, ('add', 'live'): 2, ('live', 'from'): 4, ('from', 'aragon'): 1, ('aragon', '<unk>'): 1, ('<unk>', 'to'): 420, ('to', 'trapeo'): 1, ('trapeo', '</s>'): 1, ('add', 'unite'): 1, ('unite', 'and'): 2, ('and', 'win'): 2, ('win', 'to'): 1, ('to', 'my'): 706, ('my', 'night'): 3, ('night', 'out'): 6, ('out', '</s>'): 6, ('add', 'the'): 145, ('the', 'piano'): 7, ('piano', 'bar'): 4, ('bar', 'to'): 1, ('my', '<unk>'): 43, ('<unk>', 'wilson'): 1, ('wilson', '</s>'): 2, ('add', 'spanish'): 2, ('spanish', 'harlem'): 1, ('harlem', 'incident'): 1, ('incident', 'to'): 1, ('to', 'cleaning'): 3, ('cleaning', 'the'): 4, ('the', 'house'): 8, ('house', '</s>'): 58, ('<unk>', 'of'): 159, ('of', 'blue'): 1, ('blue', 'skies'): 1, ('skies', 'in'): 1, ('in', 'indie'): 2, ('indie', 'espanol'): 3, ('espanol', 'my'): 1, ('playlist', '</s>'): 625, ('the', 'name'): 26, ('name', 'kids'): 1, ('kids', 'in'): 3, ('in', 'the'): 404, ('the', 'street'): 4, ('street', 'to'): 1, ('<unk>', 'new'): 6, ('new', 'indie'): 2, ('indie', 'mix'): 2, ('mix', '</s>'): 3, ('add', 'album'): 19, ('album', 'radar'): 1, ('radar', 'latino'): 3, ('latino', '</s>'): 6, ('add', '<unk>'): 231, ('the', 'latin'): 2, ('latin', 'pop'): 10, ('pop', 'rising'): 6, ('rising', 'playlist'): 6, ('add', 'd'): 2, ('d', 'flame'): 1, ('flame', 'to'): 2, ('the', 'dcode'): 1, ('dcode', 'playlist'): 2, ('album', 'to'): 94, ('my', 'fairy'): 4, ('fairy', 'tales'): 6, ('tales', '</s>'): 2, ('add', 'to'): 18, ('to', 'playlist'): 13, ('playlist', 'i'): 3, ('i', 'love'): 15, ('love', 'my'): 13, ('my', 'neo'): 4, ('neo', 'soul'): 4, ('soul', 'the'): 1, ('name', 'national'): 1, ('national', 'treasure'): 1, ('treasure', 'book'): 1, ('book', 'of'): 27, ('of', 'secrets'): 2, ('secrets', '</s>'): 1, ('the', 'fire'): 3, ('fire', 'and'): 4, ('and', 'the'): 67, ('the', 'wind'): 6, ('wind', 'to'): 1, ('my', 'digster'): 4, ('digster', 'future'): 3, ('future', 'hits'): 3, ('hits', 'playlist'): 14, ('add', 'caleigh'): 1, ('caleigh', 'peters'): 2, ('peters', 'to'): 1, ('my', 'women'): 14, ('women', 'of'): 36, ('of', 'country'): 3, ('country', 'list'): 1, ('list', '</s>'): 80, ('add', 'children'): 1, ('children', 'of'): 2, ('of', '<unk>'): 211, ('<unk>', '<unk>'): 810, ('the', 'playlist'): 66, ('playlist', 'named'): 23, ('named', '<unk>'): 5, ('<unk>', '</s>'): 946, ('add', 'th'): 1, ('th', '<unk>'): 3, ('my', 'bossa'): 2, ('bossa', 'nova'): 3, ('nova', 'dinner'): 2, ('dinner', 'playlist'): 12, ('<s>', 'i'): 1410, ('i', 'need'): 281, ('need', 'another'): 2, ('another', 'tune'): 9, ('tune', 'in'): 5, ('my', 'legendary'): 2, ('legendary', 'guitar'): 3, ('guitar', 'solos'): 3, ('solos', 'playlist'): 2, ('add', 'slimm'): 1, ('slimm', 'cutta'): 2, ('cutta', 'calhoun'): 2, ('calhoun', 'to'): 1, ('my', 'this'): 40, ('this', 'is'): 105, ('is', 'prince'): 3, ('prince', 'playlist'): 3, ('add', 'always'): 1, ('always', 'to'): 1, ('to', 'dena'): 1, ('dena', "'s"): 1, ("'s", 'baroque'): 1, ('baroque', 'spotify'): 2, ('spotify', 'picks'): 7, ('picks', 'playlist'): 4, ('add', 'song'): 25, ('to', '<unk>'): 106, ('add', 'an'): 23, ('an', 'album'): 37, ('my', 'list'): 13, ('list', 'la'): 1, ('la', 'mejor'): 7, ('mejor', 'musica'): 7, ('musica', 'dance'): 4, ('dance', '</s>'): 5, ('<unk>', ','): 190, (',', 'johnnie'): 1, ('johnnie', 'cope'): 1, ('cope', ','): 1, (',', 'are'): 1, ('are', 'ye'): 1, ('ye', '<unk>'): 1, ('<unk>', 'yet'): 1, ('yet', 'to'): 2, ('to', 'year'): 2, ('year', 'in'): 17, ('in', 'metal'): 4, ('metal', 'playlist'): 20, ('the', 'album'): 75, ('the', ' ...

# %%
# p(word|prev_word) = 
def probability(word, prev_words, 
                         count_n_gram, count_one_n_gram, v_siz , k=1):
  
    prev_words = prev_words.lower()
    prev_words = nltk.word_tokenize(prev_words)
    prev_word = tuple(prev_words)
   
    
    
    prev_word_count = 0
    if(prev_word in count_n_gram):
        prev_word_count = count_n_gram[prev_word]
  
    denominator = prev_word_count + k * v_siz
    prev_words.append(word)
    n_1_gram =  tuple(prev_words)
    
    whole_word_count = 0
    if(n_1_gram in count_one_n_gram):
        whole_word_count = count_one_n_gram[n_1_gram]
    
    numerator = whole_word_count + k
  
    probability = numerator / denominator
    
    
    return probability

# %%
trigram = n_gram_fun(full_q, 3)
bigram = n_gram_fun(full_q, 2)
print(bigram)
prob = probability("clem", "add", bigram,trigram, len(closed_vocab), k =1.0)
print(prob)
# Out:
# {('<s>', 'add'): 1243, ('add', 'another'): 19, ('another', 'song'): 10, ('song', 'to'): 99, ('to', 'the'): 310, ('the', '<unk>'): 634, ('<unk>', 'romantica'): 1, ('romantica', 'playlist'): 3, ('playlist', '.'): 254, ('.', '</s>'): 1958, ('</s>',): 11784, ('add', 'clem'): 1, ('clem', 'burke'): 2, ('burke', 'in'): 1, ('in', 'my'): 63, ('my', 'playlist'): 125, ('playlist', 'pre-party'): 1, ('pre-party', 'r'): 6, ('r', '&'): 22, ('&', 'b'): 33, ('b', 'jams'): 6, ('jams', '</s>'): 7, ('add', 'live'): 2, ('live', 'from'): 4, ('from', 'aragon'): 1, ('aragon', '<unk>'): 1, ('<unk>', 'to'): 420, ('to', 'trapeo'): 1, ('trapeo', '</s>'): 1, ('add', 'unite'): 1, ('unite', 'and'): 2, ('and', 'win'): 2, ('win', 'to'): 1, ('to', 'my'): 706, ('my', 'night'): 3, ('night', 'out'): 6, ('out', '</s>'): 6, ('add', 'the'): 145, ('the', 'piano'): 7, ('piano', 'bar'): 4, ('bar', 'to'): 1, ('my', '<unk>'): 43, ('<unk>', 'wilson'): 1, ('wilson', '</s>'): 2, ('add', 'spanish'): 2, ('spanish', 'harlem'): 1, ('harlem', 'incident'): 1, ('incident', 'to'): 1, ('to', 'cleaning'): 3, ('cleaning', 'the'): 4, ('the', 'house'): 8, ('house', '</s>'): 58, ('<unk>', 'of'): 159, ('of', 'blue'): 1, ('blue', 'skies'): 1, ('skies', 'in'): 1, ('in', 'indie'): 2, ('indie', 'espanol'): 3, ('espanol', 'my'): 1, ('playlist', '</s>'): 625, ('the', 'name'): 26, ('name', 'kids'): 1, ('kids', 'in'): 3, ('in', 'the'): 404, ('the', 'street'): 4, ('street', 'to'): 1, ('<unk>', 'new'): 6, ('new', 'indie'): 2, ('indie', 'mix'): 2, ('mix', '</s>'): 3, ('add', 'album'): 19, ('album', 'radar'): 1, ('radar', 'latino'): 3, ('latino', '</s>'): 6, ('add', '<unk>'): 231, ('the', 'latin'): 2, ('latin', 'pop'): 10, ('pop', 'rising'): 6, ('rising', 'playlist'): 6, ('add', 'd'): 2, ('d', 'flame'): 1, ('flame', 'to'): 2, ('the', 'dcode'): 1, ('dcode', 'playlist'): 2, ('album', 'to'): 94, ('my', 'fairy'): 4, ('fairy', 'tales'): 6, ('tales', '</s>'): 2, ('add', 'to'): 18, ('to', 'playlist'): 13, ('playlist', 'i'): 3, ('i', 'love'): 15, ('love', 'my'): 13, ('my', 'neo'): 4, ('neo', 'soul'): 4, ('soul', 'the'): 1, ('name', 'national'): 1, ('national', 'treasure'): 1, ('treasure', 'book'): 1, ('book', 'of'): 27, ('of', 'secrets'): 2, ('secrets', '</s>'): 1, ('the', 'fire'): 3, ('fire', 'and'): 4, ('and', 'the'): 67, ('the', 'wind'): 6, ('wind', 'to'): 1, ('my', 'digster'): 4, ('digster', 'future'): 3, ('future', 'hits'): 3, ('hits', 'playlist'): 14, ('add', 'caleigh'): 1, ('caleigh', 'peters'): 2, ('peters', 'to'): 1, ('my', 'women'): 14, ('women', 'of'): 36, ('of', 'country'): 3, ('country', 'list'): 1, ('list', '</s>'): 80, ('add', 'children'): 1, ('children', 'of'): 2, ('of', '<unk>'): 211, ('<unk>', '<unk>'): 810, ('the', 'playlist'): 66, ('playlist', 'named'): 23, ('named', '<unk>'): 5, ('<unk>', '</s>'): 946, ('add', 'th'): 1, ('th', '<unk>'): 3, ('my', 'bossa'): 2, ('bossa', 'nova'): 3, ('nova', 'dinner'): 2, ('dinner', 'playlist'): 12, ('<s>', 'i'): 1410, ('i', 'need'): 281, ('need', 'another'): 2, ('another', 'tune'): 9, ('tune', 'in'): 5, ('my', 'legendary'): 2, ('legendary', 'guitar'): 3, ('guitar', 'solos'): 3, ('solos', 'playlist'): 2, ('add', 'slimm'): 1, ('slimm', 'cutta'): 2, ('cutta', 'calhoun'): 2, ('calhoun', 'to'): 1, ('my', 'this'): 40, ('this', 'is'): 105, ('is', 'prince'): 3, ('prince', 'playlist'): 3, ('add', 'always'): 1, ('always', 'to'): 1, ('to', 'dena'): 1, ('dena', "'s"): 1, ("'s", 'baroque'): 1, ('baroque', 'spotify'): 2, ('spotify', 'picks'): 7, ('picks', 'playlist'): 4, ('add', 'song'): 25, ('to', '<unk>'): 106, ('add', 'an'): 23, ('an', 'album'): 37, ('my', 'list'): 13, ('list', 'la'): 1, ('la', 'mejor'): 7, ('mejor', 'musica'): 7, ('musica', 'dance'): 4, ('dance', '</s>'): 5, ('<unk>', ','): 190, (',', 'johnnie'): 1, ('johnnie', 'cope'): 1, ('cope', ','): 1, (',', 'are'): 1, ('are', 'ye'): 1, ('ye', '<unk>'): 1, ('<unk>', 'yet'): 1, ('yet', 'to'): 2, ('to', 'year'): 2, ('year', 'in'): 17, ('in', 'metal'): 4, ('metal', 'playlist'): 20, ('the', 'album'): 75, ('the', ' ...
# 0.00025303643724696357

# %%
def all_probability(pre_words, prefix,count_n_gram, count_one_n_gram, v , k=1):
  
    
    v_siz = len(v)
    
    pro = {}
    
    for word in v:
        if(len(prefix) > len(word) and prefix != '-1'):
            continue
        index = len(prefix)
        if(word[0:index] != prefix and prefix != '-1'):
            continue

        probabilit = probability(word,pre_words, 
                                   count_n_gram, count_one_n_gram, 
                                   v_siz, k)
        pro[word] = probabilit

    return pro

# %%
words = input("enter sentence\n")
pre = input("enter prefix or -1 to ignore\n")
pre = pre.lower()
# Out:
# enter sentence
# add
# enter prefix or -1 to ignore
# -1

# %%
prob = all_probability(words, pre ,unigram, bigram, closed_vocab, 1.0)
#print(prob)
new_prob = {}

ls_ans = []
for i in prob :
    ls_ans.append(prob[i])
    new_prob[prob[i]] = i
ls_ans.sort(reverse =True)
for i in range(min(len(ls_ans) , 10)):
    print(new_prob[ls_ans[i]])
# Out:
# this
# the
# a
# tune
# artist
# track
# song
# an
# album
# album

# %%
def preprexity(test_q, n):
    ans = 1
    new_test_q =[]
    for i in test_q:
        ls = []
        for j in i:
            if(j not in closed_vocab):
                ls.append('<unk>')
            else:
                ls.append(j)
        new_test_q.append(ls)
    test_q = new_test_q
    v_siz = len(vocab)
    n_gram = n_gram_fun(test_q , n)
    
    n_one_gram = n_gram_fun(test_q,n+1)
    
    for i in test_q:
        i = ["<s>"]*n+i+["</s>"]
        i = i[::-1]
        # <s> h e l l o </s>
        #</s> o l l e h <s>
        p = 0
        while(p+n+1 <= len(i)):
            word = str(i[p:p+1])
            prev_word = str(i[p+1:p+n+1][::-1])
            ans +=  math.log(probability(word, prev_word, 
                         n_gram, n_one_gram, v_siz , k=1) , 2)
            p +=1
    
       
    ans *= -1/len(test_q)
    return ans

# %%
j = preprexity(test_full_q , 1)
print(j)
# Out:
# 132.8947380491337
